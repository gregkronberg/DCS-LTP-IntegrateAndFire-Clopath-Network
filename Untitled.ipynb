# %%
import networks_3
import equations
import matplotlib.pyplot as plt
from brian2 import *
import imp
imp.reload(equations)
imp.reload(networks_3)
# Out:
# <module 'networks_3' from 'networks_3.pyc'>

# %%
exp = networks_3.exp_zenke_test()

# %%
exp.run()
# Out:
# WARNING    "w_cons" is an internal variable of group "synapses_EE", but also exists in the group-specific namespace with the value 0.0. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    "w_cons" is an internal variable of group "synapses_EI", but also exists in the group-specific namespace with the value 0.0. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# ('run duration:', '1107.28299999')

# %%
exp.rec['synapses']['EE'].w_exc_plastic[:].shape
# Out:
# (11L, 165000L)

# %%
plt.plot(exp.rec['synapses']['EE'].w_exc_plastic.T)
# Out:
# [<matplotlib.lines.Line2D at 0xbd61cf8>,
#  <matplotlib.lines.Line2D at 0x1878fac8>,
#  <matplotlib.lines.Line2D at 0x1878fb70>,
#  <matplotlib.lines.Line2D at 0x1878fc18>,
#  <matplotlib.lines.Line2D at 0x1878fcc0>,
#  <matplotlib.lines.Line2D at 0x1878fd68>,
#  <matplotlib.lines.Line2D at 0x1878fe10>,
#  <matplotlib.lines.Line2D at 0x1878feb8>,
#  <matplotlib.lines.Line2D at 0x1878ff60>,
#  <matplotlib.lines.Line2D at 0x187a3048>,
#  <matplotlib.lines.Line2D at 0x187a30f0>]

# %%
plt.plot(exp.rec['synapses']['EE'].w_cons.T)
# Out:
# [<matplotlib.lines.Line2D at 0xb59d5c0>,
#  <matplotlib.lines.Line2D at 0xb59d668>,
#  <matplotlib.lines.Line2D at 0xb59d710>,
#  <matplotlib.lines.Line2D at 0xb59d7b8>,
#  <matplotlib.lines.Line2D at 0xb59d860>,
#  <matplotlib.lines.Line2D at 0xb59d908>,
#  <matplotlib.lines.Line2D at 0xb59d9b0>,
#  <matplotlib.lines.Line2D at 0xb59da58>,
#  <matplotlib.lines.Line2D at 0xb59db00>,
#  <matplotlib.lines.Line2D at 0xb59dba8>,
#  <matplotlib.lines.Line2D at 0xb59dc50>]

# %%
exp.spike_rec
# Out:
# {'neurons': {}}
