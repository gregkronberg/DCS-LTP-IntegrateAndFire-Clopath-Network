# %%
import networks_3
import equations
import matplotlib.pyplot as plt
from brian2 import *
import imp
reload(equations)
reload(networks_3)
# Out:
# <module 'networks_3' from 'networks_3.pyc'>

# %%
neurons={'E_rate':{'t_H':1500*ms,'gamma':10.}}
trial_id = None
w_IE_init=0.2
w_FE_init=.4
reinit_W=False

# %%
exp = networks_3.exp_zenke_test_ff_plastic()

# %%
exp.run(neurons=neurons, trial_id=trial_id, w_IE_init=w_IE_init, w_FE_init=w_FE_init, reinit_W=reinit_W)
# Out:
# {'rec_variables': [], 't_H': 1.5 * second, 'gamma': 10.0, 'N': 1}
# Starting simulation at t=0. s for a duration of 12. s
# 2.0787 s (17%) simulated in 1m 0s, estimated 4m 46s remaining.
# 4.0991 s (34%) simulated in 2m 0s, estimated 3m 51s remaining.
# 6.0372 s (50%) simulated in 3m 0s, estimated 2m 58s remaining.
# 7.9979 s (66%) simulated in 4m 0s, estimated 2m 0s remaining.
# 10.0083 s (83%) simulated in 5m 0s, estimated 1m 0s remaining.
# 11.9799 s (99%) simulated in 6m 0s, estimated 1s remaining.
# 12. s (100%) simulated in 6m 0s
# 120000
# 120000
# EE 0.10000000000000012
# E_input_E 0.39999999999999936
# IE 0.19999999999999996
# global excitatory rate: <neurons_E_rate.G: array([24.65765885])>
# run  1  of  60  completed
# Starting simulation at t=12. s for a duration of 12. s
# 1.9076 s (15%) simulated in 1m 0s, estimated 5m 17s remaining.
# 3.8562 s (32%) simulated in 2m 0s, estimated 4m 13s remaining.
# 5.8092 s (48%) simulated in 3m 0s, estimated 3m 12s remaining.
# 7.7815 s (64%) simulated in 4m 0s, estimated 2m 10s remaining.
# 9.7408 s (81%) simulated in 5m 0s, estimated 1m 10s remaining.
# 11.7188 s (97%) simulated in 6m 0s, estimated 9s remaining.
# 12. s (100%) simulated in 6m 8s
# 120000
# 120000
# EE 0.10000000000000012
# E_input_E 0.39999999999999936
# IE 0.19999999999999996
# global excitatory rate: <neurons_E_rate.G: array([25.26282981])>
# run  2  of  60  completed
# Starting simulation at t=24. s for a duration of 12. s
# 1.9791 s (16%) simulated in 1m 0s, estimated 5m 4s remaining.
# 4.0645 s (33%) simulated in 2m 0s, estimated 3m 54s remaining.
# 6.3214 s (52%) simulated in 3m 0s, estimated 2m 42s remaining.
# 8.6561 s (72%) simulated in 4m 0s, estimated 1m 33s remaining.
# 11.0717 s (92%) simulated in 5m 0s, estimated 25s remaining.
# 12. s (100%) simulated in 5m 22s
# 120000
# 120000
# EE 0.0798544048917267
# E_input_E 0.43590146082078635
# IE 0.23363839084126126
# global excitatory rate: <neurons_E_rate.G: array([9.47721309])>
# run  3  of  60  completed
# Starting simulation at t=36. s for a duration of 12. s
# 2.5117 s (20%) simulated in 1m 0s, estimated 3m 47s remaining.
# 5.0448 s (42%) simulated in 2m 0s, estimated 2m 45s remaining.
# 7.5654 s (63%) simulated in 3m 0s, estimated 1m 46s remaining.
# 10.1129 s (84%) simulated in 4m 0s, estimated 45s remaining.
# 12. s (100%) simulated in 4m 44s
# 120000
# 120000
# EE 0.06462390265205335
# E_input_E 0.45732723620664173
# IE 0.24933049886168748
# global excitatory rate: <neurons_E_rate.G: array([6.26268012])>
# run  4  of  60  completed
# Starting simulation at t=48. s for a duration of 12. s
# 2.5088 s (20%) simulated in 1m 0s, estimated 3m 47s remaining.
# 5.0217 s (41%) simulated in 2m 0s, estimated 2m 47s remaining.
# 7.4383 s (61%) simulated in 3m 0s, estimated 1m 50s remaining.
# 9.7931 s (81%) simulated in 4m 0s, estimated 54s remaining.
# 12. s (100%) simulated in 4m 57s
# 120000
# 120000
# EE 0.05631610158222479
# E_input_E 0.5485478839601059
# IE 0.2660295744906869
# global excitatory rate: <neurons_E_rate.G: array([12.25487174])>
# run  5  of  60  completed
# Starting simulation at t=60. s for a duration of 12. s
# 2.2346 s (18%) simulated in 1m 0s, estimated 4m 22s remaining.
# 4.3647 s (36%) simulated in 2m 0s, estimated 3m 30s remaining.
# 6.4526 s (53%) simulated in 3m 0s, estimated 2m 35s remaining.
# 8.551 s (71%) simulated in 4m 0s, estimated 1m 37s remaining.
# 10.543 s (87%) simulated in 5m 0s, estimated 41s remaining.
# 12. s (100%) simulated in 5m 45s
# 120000
# 120000
# EE 0.05064775303324679
# E_input_E 0.7135745157097245
# IE 0.29487997475234556
# global excitatory rate: <neurons_E_rate.G: array([24.31171785])>
# run  6  of  60  completed
# Starting simulation at t=72. s for a duration of 12. s
# 1.8799 s (15%) simulated in 1m 0s, estimated 5m 23s remaining.
# 3.6779 s (30%) simulated in 2m 0s, estimated 4m 32s remaining.
# 5.4896 s (45%) simulated in 3m 0s, estimated 3m 33s remaining.
# 7.2647 s (60%) simulated in 4m 0s, estimated 2m 36s remaining.
# 8.9875 s (74%) simulated in 5m 0s, estimated 1m 41s remaining.
# 10.6764 s (88%) simulated in 6m 0s, estimated 45s remaining.
# 12. s (100%) simulated in 6m 47s
# 120000
# 120000
# EE 0.046247116952849575
# E_input_E 0.894980521425195
# IE 0.34108715910031706
# global excitatory rate: <neurons_E_rate.G: array([36.35496567])>
# run  7  of  60  completed
# Starting simulation at t=84. s for a duration of 12. s
# 1.6231 s (13%) simulated in 1m 0s, estimated 6m 24s remaining.
# 3.1412 s (26%) simulated in 2m 0s, estimated 5m 38s remaining.
# 4.7399 s (39%) simulated in 3m 0s, estimated 4m 36s remaining.
# 6.2087 s (51%) simulated in 4m 0s, estimated 3m 44s remaining.
# 7.7556 s (64%) simulated in 5m 0s, estimated 2m 44s remaining.
# 9.1976 s (76%) simulated in 6m 0s, estimated 1m 50s remaining.
# 10.68 s (89%) simulated in 7m 0s, estimated 52s remaining.
# 12. s (100%) simulated in 7m 57s
# 120000
# 120000
# EE 0.04184791058879115
# E_input_E 1.1160035486552489
# IE 0.403469039797762
# global excitatory rate: <neurons_E_rate.G: array([48.41775547])>
# run  8  of  60  completed
# Starting simulation at t=96. s for a duration of 12. s
# 1.451 s (12%) simulated in 1m 0s, estimated 7m 16s remaining.
# 2.8202 s (23%) simulated in 2m 0s, estimated 6m 31s remaining.
# 4.2515 s (35%) simulated in 3m 0s, estimated 5m 28s remaining.
# 5.6272 s (46%) simulated in 4m 0s, estimated 4m 32s remaining.
# 7.0153 s (58%) simulated in 5m 0s, estimated 3m 33s remaining.
# 8.3704 s (69%) simulated in 6m 0s, estimated 2m 36s remaining.
# 9.7336 s (81%) simulated in 7m 0s, estimated 1m 38s remaining.
# 11.0885 s (92%) simulated in 8m 0s, estimated 39s remaining.
# 12. s (100%) simulated in 8m 42s
# 120000
# 120000
# EE 0.03828286702571954
# E_input_E 1.2908935466700517
# IE 0.4813396166613479
# global excitatory rate: <neurons_E_rate.G: array([57.69340402])>
# run  9  of  60  completed
# Starting simulation at t=108. s for a duration of 12. s
# 1.3775 s (11%) simulated in 1m 0s, estimated 7m 43s remaining.
# 2.6927 s (22%) simulated in 2m 0s, estimated 6m 55s remaining.
# 4.0721 s (33%) simulated in 3m 0s, estimated 5m 50s remaining.
# 5.3842 s (44%) simulated in 4m 0s, estimated 4m 55s remaining.
# 6.7146 s (55%) simulated in 5m 0s, estimated 3m 56s remaining.
# 8.0505 s (67%) simulated in 6m 0s, estimated 2m 57s remaining.
# 9.3475 s (77%) simulated in 7m 0s, estimated 1m 59s remaining.
# 10.6956 s (89%) simulated in 8m 0s, estimated 59s remaining.
# 11.985 s (99%) simulated in 9m 0s, estimated 1s remaining.
# 12. s (100%) simulated in 9m 0s
# 120000
# 120000
# EE 0.0361354817380147
# E_input_E 1.3662951522668376
# IE 0.56342403502418
# global excitatory rate: <neurons_E_rate.G: array([59.58888435])>
# run  10  of  60  completed
# Starting simulation at t=120. s for a duration of 12. s
# 1.3839 s (11%) simulated in 1m 0s, estimated 7m 40s remaining.
# 2.7012 s (22%) simulated in 2m 0s, estimated 6m 53s remaining.
# 4.0463 s (33%) simulated in 3m 0s, estimated 5m 54s remaining.
# 5.3513 s (44%) simulated in 4m 0s, estimated 4m 58s remaining.
# 6.6737 s (55%) simulated in 5m 0s, estimated 3m 59s remaining.
# 8.0449 s (67%) simulated in 6m 0s, estimated 2m 57s remaining.
# 9.3524 s (77%) simulated in 7m 0s, estimated 1m 59s remaining.
# 10.7115 s (89%) simulated in 8m 0s, estimated 58s remaining.
# 12. s (100%) simulated in 8m 58s
# 120000
# 120000
# EE 0.03478700054396206
# E_input_E 1.3995130690661415
# IE 0.6399964118358062
# global excitatory rate: <neurons_E_rate.G: array([58.781011])>
# run  11  of  60  completed
# Starting simulation at t=132. s for a duration of 12. s
# 1.4113 s (11%) simulated in 1m 0s, estimated 7m 30s remaining.
# 2.7348 s (22%) simulated in 2m 0s, estimated 6m 47s remaining.
# 4.1274 s (34%) simulated in 3m 0s, estimated 5m 43s remaining.
# 5.4383 s (45%) simulated in 4m 0s, estimated 4m 50s remaining.
# 6.7779 s (56%) simulated in 5m 0s, estimated 3m 51s remaining.
# 8.1279 s (67%) simulated in 6m 0s, estimated 2m 52s remaining.
# 9.4792 s (78%) simulated in 7m 0s, estimated 1m 52s remaining.
# 10.8798 s (90%) simulated in 8m 0s, estimated 49s remaining.
# 12. s (100%) simulated in 8m 51s
# 120000
# 120000
# EE 0.03408285726566346
# E_input_E 1.4062664357622905
# IE 0.7088375467007045
# global excitatory rate: <neurons_E_rate.G: array([57.48357661])>
# run  12  of  60  completed
# Starting simulation at t=144. s for a duration of 12. s
# 1.4304 s (11%) simulated in 1m 0s, estimated 7m 23s remaining.
# 2.8072 s (23%) simulated in 2m 0s, estimated 6m 33s remaining.
# 4.2584 s (35%) simulated in 3m 0s, estimated 5m 27s remaining.
# 5.5966 s (46%) simulated in 4m 0s, estimated 4m 35s remaining.
# 6.9979 s (58%) simulated in 5m 0s, estimated 3m 34s remaining.
# 8.3666 s (69%) simulated in 6m 0s, estimated 2m 36s remaining.
# 9.7306 s (81%) simulated in 7m 0s, estimated 1m 38s remaining.
# 11.1342 s (92%) simulated in 8m 0s, estimated 37s remaining.
# 12. s (100%) simulated in 8m 39s
# 120000
# 120000
# EE 0.03332050969608333
# E_input_E 1.408268402383089
# IE 0.7700661978263673
# global excitatory rate: <neurons_E_rate.G: array([56.43114343])>
# run  13  of  60  completed
# Starting simulation at t=156. s for a duration of 12. s
# 1.3956 s (11%) simulated in 1m 0s, estimated 7m 36s remaining.
# 2.747 s (22%) simulated in 2m 0s, estimated 6m 44s remaining.
# 4.1278 s (34%) simulated in 3m 0s, estimated 5m 43s remaining.
# 5.4635 s (45%) simulated in 4m 0s, estimated 4m 47s remaining.
# 6.8361 s (56%) simulated in 5m 0s, estimated 3m 47s remaining.
# 8.1842 s (68%) simulated in 6m 0s, estimated 2m 48s remaining.
# 9.5349 s (79%) simulated in 7m 0s, estimated 1m 49s remaining.
# 10.9468 s (91%) simulated in 8m 0s, estimated 46s remaining.
# 12. s (100%) simulated in 8m 47s
# 120000
# 120000
# EE 0.03299191853008193
# E_input_E 1.4087531154574184
# IE 0.8259728736214834
# global excitatory rate: <neurons_E_rate.G: array([55.31577669])>
# run  14  of  60  completed
# Starting simulation at t=168. s for a duration of 12. s
# 1.3801 s (11%) simulated in 1m 0s, estimated 7m 42s remaining.
# 2.7023 s (22%) simulated in 2m 0s, estimated 6m 53s remaining.
# 4.0881 s (34%) simulated in 3m 0s, estimated 5m 48s remaining.
# 5.4567 s (45%) simulated in 4m 0s, estimated 4m 48s remaining.
# 6.841 s (57%) simulated in 5m 0s, estimated 3m 46s remaining.
# 8.2379 s (68%) simulated in 6m 0s, estimated 2m 44s remaining.
# 9.635 s (80%) simulated in 7m 0s, estimated 1m 43s remaining.
# 11.0403 s (92%) simulated in 8m 0s, estimated 42s remaining.
# 12. s (100%) simulated in 8m 43s
# 120000
# 120000
# EE 0.032558328007152366
# E_input_E 1.406908102447161
# IE 0.877399556209415
# global excitatory rate: <neurons_E_rate.G: array([54.59632217])>
# run  15  of  60  completed
# Starting simulation at t=180. s for a duration of 12. s
# 1.4455 s (12%) simulated in 1m 0s, estimated 7m 18s remaining.
# 2.7817 s (23%) simulated in 2m 0s, estimated 6m 38s remaining.
# 4.1723 s (34%) simulated in 3m 0s, estimated 5m 38s remaining.
# 5.5187 s (45%) simulated in 4m 0s, estimated 4m 42s remaining.
# 6.9058 s (57%) simulated in 5m 0s, estimated 3m 41s remaining.
# 8.2804 s (69%) simulated in 6m 0s, estimated 2m 42s remaining.
# 9.6471 s (80%) simulated in 7m 0s, estimated 1m 42s remaining.
# 11.0389 s (91%) simulated in 8m 0s, estimated 42s remaining.
# 12. s (100%) simulated in 8m 43s
# 120000
# 120000
# EE 0.032069395382361636
# E_input_E 1.4054216906072483
# IE 0.9247875662843573
# global excitatory rate: <neurons_E_rate.G: array([54.39836799])>
# run  16  of  60  completed
# Starting simulation at t=192. s for a duration of 12. s
# 1.4061 s (11%) simulated in 1m 0s, estimated 7m 32s remaining.
# 2.7684 s (23%) simulated in 2m 0s, estimated 6m 40s remaining.
# 4.1719 s (34%) simulated in 3m 0s, estimated 5m 38s remaining.
# 5.5272 s (46%) simulated in 4m 0s, estimated 4m 41s remaining.
# 6.925 s (57%) simulated in 5m 0s, estimated 3m 40s remaining.
# 8.2937 s (69%) simulated in 6m 0s, estimated 2m 41s remaining.
# 9.6856 s (80%) simulated in 7m 0s, estimated 1m 40s remaining.
# 11.0845 s (92%) simulated in 8m 0s, estimated 40s remaining.
# 12. s (100%) simulated in 8m 40s
# 120000
# 120000
# EE 0.031641077167005406
# E_input_E 1.4046558830857983
# IE 0.9687926437458623
# global excitatory rate: <neurons_E_rate.G: array([53.93533578])>
# run  17  of  60  completed
# Starting simulation at t=204. s for a duration of 12. s
# 1.4459 s (12%) simulated in 1m 0s, estimated 7m 18s remaining.
# 2.7987 s (23%) simulated in 2m 0s, estimated 6m 35s remaining.
# 4.2249 s (35%) simulated in 3m 0s, estimated 5m 31s remaining.
# 5.5902 s (46%) simulated in 4m 0s, estimated 4m 35s remaining.
# 7.0096 s (58%) simulated in 5m 0s, estimated 3m 34s remaining.
# 8.3943 s (69%) simulated in 6m 0s, estimated 2m 35s remaining.
# 9.8023 s (81%) simulated in 7m 0s, estimated 1m 34s remaining.
# 11.1978 s (93%) simulated in 8m 0s, estimated 34s remaining.
# 12. s (100%) simulated in 8m 35s
# 120000
# 120000
# EE 0.031493070245287115
# E_input_E 1.4015416906764897
# IE 1.0098969820670844
# global excitatory rate: <neurons_E_rate.G: array([53.7054785])>
# run  18  of  60  completed
# Starting simulation at t=216. s for a duration of 12. s
# 1.4499 s (12%) simulated in 1m 0s, estimated 7m 17s remaining.
# 2.8096 s (23%) simulated in 2m 0s, estimated 6m 33s remaining.
# 4.2348 s (35%) simulated in 3m 0s, estimated 5m 30s remaining.
# 5.6053 s (46%) simulated in 4m 0s, estimated 4m 34s remaining.
# 7.0503 s (58%) simulated in 5m 0s, estimated 3m 31s remaining.
# 8.4623 s (70%) simulated in 6m 0s, estimated 2m 31s remaining.
# 9.8903 s (82%) simulated in 7m 0s, estimated 1m 30s remaining.
# 11.2788 s (93%) simulated in 8m 0s, estimated 31s remaining.
# 12. s (100%) simulated in 8m 31s
# 120000
# 120000
# EE 0.03125180584433243
# E_input_E 1.3980172585013237
# IE 1.0479842923376759
# global excitatory rate: <neurons_E_rate.G: array([53.77698384])>
# run  19  of  60  completed
# Starting simulation at t=228. s for a duration of 12. s
# 1.4517 s (12%) simulated in 1m 0s, estimated 7m 16s remaining.
# 2.7843 s (23%) simulated in 2m 0s, estimated 6m 37s remaining.
# 4.1883 s (34%) simulated in 3m 0s, estimated 5m 36s remaining.
# 5.554 s (46%) simulated in 4m 0s, estimated 4m 39s remaining.
# 6.9686 s (58%) simulated in 5m 0s, estimated 3m 37s remaining.
# 8.3545 s (69%) simulated in 6m 0s, estimated 2m 37s remaining.
# 9.7359 s (81%) simulated in 7m 0s, estimated 1m 38s remaining.
# 11.1338 s (92%) simulated in 8m 0s, estimated 37s remaining.
# 12. s (100%) simulated in 8m 39s
# 120000
# 120000
# EE 0.03106147844413768
# E_input_E 1.3953389466983483
# IE 1.0845843113646059
# global excitatory rate: <neurons_E_rate.G: array([53.53549673])>
# run  20  of  60  completed
# Starting simulation at t=240. s for a duration of 12. s
# 1.4301 s (11%) simulated in 1m 0s, estimated 7m 23s remaining.
# 2.7815 s (23%) simulated in 2m 0s, estimated 6m 38s remaining.
# 4.1812 s (34%) simulated in 3m 0s, estimated 5m 37s remaining.
# 5.5748 s (46%) simulated in 4m 0s, estimated 4m 37s remaining.
# 6.981 s (58%) simulated in 5m 0s, estimated 3m 36s remaining.
# 8.3689 s (69%) simulated in 6m 0s, estimated 2m 36s remaining.
# 9.7429 s (81%) simulated in 7m 0s, estimated 1m 37s remaining.
# 11.1467 s (92%) simulated in 8m 0s, estimated 37s remaining.
# 12. s (100%) simulated in 8m 38s
# 120000
# 120000
# EE 0.030820156087348602
# E_input_E 1.391896072550086
# IE 1.1189357905993982
# global excitatory rate: <neurons_E_rate.G: array([53.71276571])>
# run  21  of  60  completed
# Starting simulation at t=252. s for a duration of 12. s
# 1.4382 s (11%) simulated in 1m 0s, estimated 7m 21s remaining.
# 2.7769 s (23%) simulated in 2m 0s, estimated 6m 39s remaining.
# 4.2113 s (35%) simulated in 3m 0s, estimated 5m 33s remaining.
# 5.58 s (46%) simulated in 4m 0s, estimated 4m 36s remaining.
# 6.9707 s (58%) simulated in 5m 0s, estimated 3m 36s remaining.
# 8.3467 s (69%) simulated in 6m 0s, estimated 2m 38s remaining.
# 9.7494 s (81%) simulated in 7m 0s, estimated 1m 37s remaining.
# 11.1615 s (93%) simulated in 8m 0s, estimated 36s remaining.
# 12. s (100%) simulated in 8m 37s
# 120000
# 120000
# EE 0.030742486410299547
# E_input_E 1.3884827887127051
# IE 1.1515224825468218
# global excitatory rate: <neurons_E_rate.G: array([53.6437745])>
# run  22  of  60  completed
# Starting simulation at t=264. s for a duration of 12. s
# 1.4502 s (12%) simulated in 1m 0s, estimated 7m 17s remaining.
# 2.8294 s (23%) simulated in 2m 0s, estimated 6m 29s remaining.
# 4.2517 s (35%) simulated in 3m 0s, estimated 5m 28s remaining.
# 5.5995 s (46%) simulated in 4m 0s, estimated 4m 34s remaining.
# 7.0151 s (58%) simulated in 5m 0s, estimated 3m 33s remaining.
# 8.4475 s (70%) simulated in 6m 0s, estimated 2m 31s remaining.
# 9.9341 s (82%) simulated in 7m 0s, estimated 1m 27s remaining.
# 11.3883 s (94%) simulated in 8m 0s, estimated 26s remaining.
# 12. s (100%) simulated in 8m 26s
# 120000
# 120000
# EE 0.030533502695522286
# E_input_E 1.3850928219099221
# IE 1.1820465605004646
# global excitatory rate: <neurons_E_rate.G: array([53.95273676])>
# run  23  of  60  completed
# Starting simulation at t=276. s for a duration of 12. s
# 1.4712 s (12%) simulated in 1m 0s, estimated 7m 9s remaining.
# 2.8466 s (23%) simulated in 2m 0s, estimated 6m 26s remaining.
# 4.2778 s (35%) simulated in 3m 0s, estimated 5m 25s remaining.
# 5.6385 s (46%) simulated in 4m 0s, estimated 4m 31s remaining.
# 7.0478 s (58%) simulated in 5m 0s, estimated 3m 31s remaining.
# 8.4253 s (70%) simulated in 6m 0s, estimated 2m 33s remaining.
# 9.8197 s (81%) simulated in 7m 0s, estimated 1m 33s remaining.
# 11.1911 s (93%) simulated in 8m 0s, estimated 35s remaining.
# 12. s (100%) simulated in 8m 35s
# 120000
# 120000
# EE 0.030615683852380567
# E_input_E 1.381791955867498
# IE 1.211663152269609
# global excitatory rate: <neurons_E_rate.G: array([54.32014814])>
# run  24  of  60  completed
# Starting simulation at t=288. s for a duration of 12. s
# 1.446 s (12%) simulated in 1m 0s, estimated 7m 18s remaining.
# 2.8105 s (23%) simulated in 2m 0s, estimated 6m 32s remaining.
# 4.2058 s (35%) simulated in 3m 0s, estimated 5m 34s remaining.
# 5.5588 s (46%) simulated in 4m 0s, estimated 4m 38s remaining.
# 6.9422 s (57%) simulated in 5m 0s, estimated 3m 39s remaining.
# 8.312 s (69%) simulated in 6m 0s, estimated 2m 40s remaining.
# 9.7052 s (80%) simulated in 7m 0s, estimated 1m 39s remaining.
# 11.0965 s (92%) simulated in 8m 0s, estimated 39s remaining.
# 12. s (100%) simulated in 8m 41s
# 120000
# 120000
# EE 0.03070092191590173
# E_input_E 1.378507925494247
# IE 1.2400720797484097
# global excitatory rate: <neurons_E_rate.G: array([54.85139989])>
# run  25  of  60  completed
# Starting simulation at t=300. s for a duration of 12. s
# 1.4154 s (11%) simulated in 1m 0s, estimated 7m 29s remaining.
# 2.7543 s (22%) simulated in 2m 0s, estimated 6m 43s remaining.
# 4.1695 s (34%) simulated in 3m 0s, estimated 5m 38s remaining.
# 5.5497 s (46%) simulated in 4m 0s, estimated 4m 39s remaining.
# 6.9747 s (58%) simulated in 5m 0s, estimated 3m 36s remaining.
# 8.3712 s (69%) simulated in 6m 0s, estimated 2m 36s remaining.
# 9.7792 s (81%) simulated in 7m 0s, estimated 1m 35s remaining.
# 11.1569 s (92%) simulated in 8m 0s, estimated 36s remaining.
# 12. s (100%) simulated in 8m 38s
# 120000
# 120000
# EE 0.030340426191161885
# E_input_E 1.3752233557824745
# IE 1.2675667971973692
# global excitatory rate: <neurons_E_rate.G: array([54.66138484])>
# run  26  of  60  completed
# Starting simulation at t=312. s for a duration of 12. s
# 1.4407 s (12%) simulated in 1m 0s, estimated 7m 20s remaining.
# 2.7941 s (23%) simulated in 2m 0s, estimated 6m 35s remaining.
# 4.2311 s (35%) simulated in 3m 0s, estimated 5m 31s remaining.
# 5.6015 s (46%) simulated in 4m 0s, estimated 4m 34s remaining.
# 7.0176 s (58%) simulated in 5m 0s, estimated 3m 33s remaining.
# 8.3763 s (69%) simulated in 6m 0s, estimated 2m 36s remaining.
# 9.7776 s (81%) simulated in 7m 0s, estimated 1m 35s remaining.
# 11.1687 s (93%) simulated in 8m 0s, estimated 36s remaining.
# 12. s (100%) simulated in 8m 36s
# 120000
# 120000
# EE 0.030348998765991782
# E_input_E 1.3720747965172162
# IE 1.2938882203672977
# global excitatory rate: <neurons_E_rate.G: array([54.85842209])>
# run  27  of  60  completed
# Starting simulation at t=0.324 ks for a duration of 12. s
# 1.4474 s (12%) simulated in 1m 0s, estimated 7m 18s remaining.
# 2.8232 s (23%) simulated in 2m 0s, estimated 6m 30s remaining.
# 4.2577 s (35%) simulated in 3m 0s, estimated 5m 27s remaining.
# 5.6176 s (46%) simulated in 4m 0s, estimated 4m 33s remaining.
# 7.0192 s (58%) simulated in 5m 0s, estimated 3m 33s remaining.
# 8.3942 s (69%) simulated in 6m 0s, estimated 2m 35s remaining.
# 9.7615 s (81%) simulated in 7m 0s, estimated 1m 36s remaining.
# 11.1375 s (92%) simulated in 8m 0s, estimated 37s remaining.
# 12. s (100%) simulated in 8m 38s
# 120000
# 120000
# EE 0.030506419376373797
# E_input_E 1.3689375252690295
# IE 1.318788659858799
# global excitatory rate: <neurons_E_rate.G: array([55.06319252])>
# run  28  of  60  completed
# Starting simulation at t=0.336 ks for a duration of 12. s
# 1.4449 s (12%) simulated in 1m 0s, estimated 7m 18s remaining.
# 2.8143 s (23%) simulated in 2m 0s, estimated 6m 32s remaining.
# 4.2453 s (35%) simulated in 3m 0s, estimated 5m 29s remaining.
# 5.6214 s (46%) simulated in 4m 0s, estimated 4m 32s remaining.
# 7.0028 s (58%) simulated in 5m 0s, estimated 3m 34s remaining.
# 8.3484 s (69%) simulated in 6m 0s, estimated 2m 37s remaining.
# 9.7109 s (80%) simulated in 7m 0s, estimated 1m 39s remaining.
# 11.0988 s (92%) simulated in 8m 0s, estimated 39s remaining.
# 12. s (100%) simulated in 8m 40s
# 120000
# 120000
# EE 0.03034995881264583
# E_input_E 1.3658334732033606
# IE 1.3426850265081363
# global excitatory rate: <neurons_E_rate.G: array([55.3357417])>
# run  29  of  60  completed
# Starting simulation at t=0.348 ks for a duration of 12. s
# 1.413 s (11%) simulated in 1m 0s, estimated 7m 30s remaining.
# 2.7336 s (22%) simulated in 2m 0s, estimated 6m 47s remaining.
# 4.1125 s (34%) simulated in 3m 0s, estimated 5m 45s remaining.
# 5.4581 s (45%) simulated in 4m 0s, estimated 4m 48s remaining.
# 6.8193 s (56%) simulated in 5m 0s, estimated 3m 48s remaining.
# 8.1807 s (68%) simulated in 6m 0s, estimated 2m 48s remaining.
# 9.5809 s (79%) simulated in 7m 0s, estimated 1m 46s remaining.
# 10.9828 s (91%) simulated in 8m 0s, estimated 44s remaining.
# 12. s (100%) simulated in 8m 47s
# 120000
# 120000
# EE 0.030373624887231162
# E_input_E 1.3627887515441952
# IE 1.3660801227024235
# global excitatory rate: <neurons_E_rate.G: array([55.7673284])>
# run  30  of  60  completed
# Starting simulation at t=0.36 ks for a duration of 12. s
# 1.3821 s (11%) simulated in 1m 0s, estimated 7m 41s remaining.
# 2.7072 s (22%) simulated in 2m 0s, estimated 6m 52s remaining.
# 4.0934 s (34%) simulated in 3m 0s, estimated 5m 48s remaining.
# 5.4344 s (45%) simulated in 4m 0s, estimated 4m 50s remaining.
# 6.7987 s (56%) simulated in 5m 0s, estimated 3m 50s remaining.
# 8.1842 s (68%) simulated in 6m 0s, estimated 2m 48s remaining.
# 9.5697 s (79%) simulated in 7m 0s, estimated 1m 47s remaining.
# 10.956 s (91%) simulated in 8m 0s, estimated 46s remaining.
# 12. s (100%) simulated in 8m 47s
# 120000
# 120000
# EE 0.030338675681342426
# E_input_E 1.3597809983528615
# IE 1.3887396915029944
# global excitatory rate: <neurons_E_rate.G: array([55.88235791])>
# run  31  of  60  completed
# Starting simulation at t=0.372 ks for a duration of 12. s
# 1.4052 s (11%) simulated in 1m 0s, estimated 7m 32s remaining.
# 2.7213 s (22%) simulated in 2m 0s, estimated 6m 49s remaining.
# 4.1143 s (34%) simulated in 3m 0s, estimated 5m 45s remaining.
# 5.4693 s (45%) simulated in 4m 0s, estimated 4m 47s remaining.
# 6.8421 s (57%) simulated in 5m 0s, estimated 3m 46s remaining.
# 8.1869 s (68%) simulated in 6m 0s, estimated 2m 48s remaining.
# 9.519 s (79%) simulated in 7m 0s, estimated 1m 49s remaining.
# 10.9074 s (90%) simulated in 8m 0s, estimated 48s remaining.
# 12. s (100%) simulated in 8m 49s
# 120000
# 120000
# EE 0.030429164335158073
# E_input_E 1.356804693654643
# IE 1.4110339763211095
# global excitatory rate: <neurons_E_rate.G: array([56.16969687])>
# run  32  of  60  completed
# Starting simulation at t=0.384 ks for a duration of 12. s
# 1.3986 s (11%) simulated in 1m 0s, estimated 7m 35s remaining.
# 2.7306 s (22%) simulated in 2m 0s, estimated 6m 47s remaining.
# 4.1099 s (34%) simulated in 3m 0s, estimated 5m 46s remaining.
# 5.4556 s (45%) simulated in 4m 0s, estimated 4m 48s remaining.
# 6.8402 s (57%) simulated in 5m 0s, estimated 3m 46s remaining.
# 8.2382 s (68%) simulated in 6m 0s, estimated 2m 44s remaining.
# 9.5859 s (79%) simulated in 7m 0s, estimated 1m 46s remaining.
# 10.9653 s (91%) simulated in 8m 0s, estimated 45s remaining.
# 12. s (100%) simulated in 8m 47s
# 120000
# 120000
# EE 0.030592164040813278
# E_input_E 1.3538805932184526
# IE 1.4323667662511026
# global excitatory rate: <neurons_E_rate.G: array([56.76307701])>
# run  33  of  60  completed
# Starting simulation at t=0.396 ks for a duration of 12. s
# 1.398 s (11%) simulated in 1m 0s, estimated 7m 35s remaining.
# 2.7011 s (22%) simulated in 2m 0s, estimated 6m 53s remaining.
# 4.1091 s (34%) simulated in 3m 0s, estimated 5m 46s remaining.
# 5.4773 s (45%) simulated in 4m 0s, estimated 4m 46s remaining.
# 6.8415 s (57%) simulated in 5m 0s, estimated 3m 46s remaining.
# 8.2117 s (68%) simulated in 6m 0s, estimated 2m 46s remaining.
# 9.5513 s (79%) simulated in 7m 0s, estimated 1m 48s remaining.
# 10.9185 s (90%) simulated in 8m 0s, estimated 48s remaining.
# 12. s (100%) simulated in 8m 50s
# 120000
# 120000
# EE 0.030479855441342962
# E_input_E 1.3509705479461287
# IE 1.453248008339564
# global excitatory rate: <neurons_E_rate.G: array([56.869565])>
# run  34  of  60  completed
# Starting simulation at t=0.408 ks for a duration of 12. s
# 1.4169 s (11%) simulated in 1m 0s, estimated 7m 28s remaining.
# 2.7535 s (22%) simulated in 2m 0s, estimated 6m 43s remaining.
# 4.1194 s (34%) simulated in 3m 0s, estimated 5m 44s remaining.
# 5.4995 s (45%) simulated in 4m 0s, estimated 4m 44s remaining.
# 6.8596 s (57%) simulated in 5m 0s, estimated 3m 45s remaining.
# 8.2259 s (68%) simulated in 6m 0s, estimated 2m 45s remaining.
# 9.5612 s (79%) simulated in 7m 0s, estimated 1m 47s remaining.
# 10.9471 s (91%) simulated in 8m 0s, estimated 46s remaining.
# 12. s (100%) simulated in 8m 50s
# 120000
# 120000
# EE 0.03071050904830128
# E_input_E 1.348104480068717
# IE 1.4735069392586393
# global excitatory rate: <neurons_E_rate.G: array([57.20376097])>
# run  35  of  60  completed
# Starting simulation at t=0.42 ks for a duration of 12. s
# 1.3768 s (11%) simulated in 1m 0s, estimated 7m 43s remaining.
# 2.6892 s (22%) simulated in 2m 0s, estimated 6m 56s remaining.
# 4.0562 s (33%) simulated in 3m 0s, estimated 5m 53s remaining.
# 5.3914 s (44%) simulated in 4m 0s, estimated 4m 54s remaining.
# 6.7428 s (56%) simulated in 5m 0s, estimated 3m 54s remaining.
# 8.1048 s (67%) simulated in 6m 0s, estimated 2m 53s remaining.
# 9.4331 s (78%) simulated in 7m 0s, estimated 1m 54s remaining.
# 10.8203 s (90%) simulated in 8m 0s, estimated 52s remaining.
# 12. s (100%) simulated in 8m 53s
# 120000
# 120000
# EE 0.030942765380561333
# E_input_E 1.3452957560125147
# IE 1.4930818797783638
# global excitatory rate: <neurons_E_rate.G: array([57.325573])>
# run  36  of  60  completed
# Starting simulation at t=0.432 ks for a duration of 12. s
# 1.3759 s (11%) simulated in 1m 0s, estimated 7m 43s remaining.
# 2.6616 s (22%) simulated in 2m 0s, estimated 7m 1s remaining.
# 4.0294 s (33%) simulated in 3m 0s, estimated 5m 56s remaining.
# 5.359 s (44%) simulated in 4m 0s, estimated 4m 57s remaining.
# 6.7157 s (55%) simulated in 5m 0s, estimated 3m 56s remaining.
# 8.0814 s (67%) simulated in 6m 0s, estimated 2m 55s remaining.
# 9.4243 s (78%) simulated in 7m 0s, estimated 1m 55s remaining.
# 10.7888 s (89%) simulated in 8m 0s, estimated 54s remaining.
# 12. s (100%) simulated in 8m 56s
# 120000
# 120000
# EE 0.031140696585884538
# E_input_E 1.3424832408541274
# IE 1.5122612706499257
# global excitatory rate: <neurons_E_rate.G: array([57.48643009])>
# run  37  of  60  completed
# Starting simulation at t=0.444 ks for a duration of 12. s
# 1.3833 s (11%) simulated in 1m 0s, estimated 7m 41s remaining.
# 2.6961 s (22%) simulated in 2m 0s, estimated 6m 54s remaining.
# 4.0854 s (34%) simulated in 3m 0s, estimated 5m 49s remaining.
# 5.4228 s (45%) simulated in 4m 0s, estimated 4m 51s remaining.
# 6.8115 s (56%) simulated in 5m 0s, estimated 3m 49s remaining.
# 8.1525 s (67%) simulated in 6m 0s, estimated 2m 50s remaining.
# 9.4498 s (78%) simulated in 7m 0s, estimated 1m 53s remaining.
# 10.8176 s (90%) simulated in 8m 0s, estimated 52s remaining.
# 12. s (100%) simulated in 8m 54s
# 120000
# 120000
# EE 0.03126578825020412
# E_input_E 1.3397437603287818
# IE 1.5310497719307252
# global excitatory rate: <neurons_E_rate.G: array([57.7051757])>
# run  38  of  60  completed
# Starting simulation at t=0.456 ks for a duration of 12. s
# 1.3737 s (11%) simulated in 1m 0s, estimated 7m 44s remaining.
# 2.6866 s (22%) simulated in 2m 0s, estimated 6m 56s remaining.
# 4.0726 s (33%) simulated in 3m 0s, estimated 5m 50s remaining.
# 5.4074 s (45%) simulated in 4m 0s, estimated 4m 53s remaining.
# 6.7325 s (56%) simulated in 5m 0s, estimated 3m 55s remaining.
# 8.0883 s (67%) simulated in 6m 0s, estimated 2m 54s remaining.
# 9.4204 s (78%) simulated in 7m 0s, estimated 1m 55s remaining.
# 10.7881 s (89%) simulated in 8m 0s, estimated 54s remaining.
# 12. s (100%) simulated in 8m 55s
# 120000
# 120000
# EE 0.03151054390780691
# E_input_E 1.3369952913961427
# IE 1.5493819994349347
# global excitatory rate: <neurons_E_rate.G: array([58.45325718])>
# run  39  of  60  completed
# Starting simulation at t=0.468 ks for a duration of 12. s
# 1.4288 s (11%) simulated in 1m 0s, estimated 7m 24s remaining.
# 2.789 s (23%) simulated in 2m 0s, estimated 6m 36s remaining.
# 4.1636 s (34%) simulated in 3m 0s, estimated 5m 39s remaining.
# 5.4892 s (45%) simulated in 4m 0s, estimated 4m 45s remaining.
# 6.8504 s (57%) simulated in 5m 0s, estimated 3m 46s remaining.
# 8.1926 s (68%) simulated in 6m 0s, estimated 2m 47s remaining.
# 9.5325 s (79%) simulated in 7m 0s, estimated 1m 49s remaining.
# 10.9116 s (90%) simulated in 8m 0s, estimated 48s remaining.
# 12. s (100%) simulated in 8m 49s
# 120000
# 120000
# EE 0.03193104992065909
# E_input_E 1.3343001062219522
# IE 1.5670405147685065
# global excitatory rate: <neurons_E_rate.G: array([58.3265651])>
# run  40  of  60  completed
# Starting simulation at t=0.48 ks for a duration of 12. s
# 1.3631 s (11%) simulated in 1m 0s, estimated 7m 48s remaining.
# 2.6546 s (22%) simulated in 2m 0s, estimated 7m 3s remaining.
# 4.0058 s (33%) simulated in 3m 0s, estimated 5m 59s remaining.
# 5.2982 s (44%) simulated in 4m 0s, estimated 5m 4s remaining.
# 6.635 s (55%) simulated in 5m 0s, estimated 4m 3s remaining.
# 7.9683 s (66%) simulated in 6m 0s, estimated 3m 2s remaining.
# 9.2423 s (77%) simulated in 7m 0s, estimated 2m 5s remaining.
# 10.6171 s (88%) simulated in 8m 0s, estimated 1m 3s remaining.
# 11.9137 s (99%) simulated in 9m 0s, estimated 4s remaining.
# 12. s (100%) simulated in 9m 4s
# 120000
# 120000
# EE 0.03195606948937917
# E_input_E 1.3315786759777
# IE 1.584377015863068
# global excitatory rate: <neurons_E_rate.G: array([58.87843576])>
# run  41  of  60  completed
# Starting simulation at t=0.492 ks for a duration of 12. s
# 1.3457 s (11%) simulated in 1m 0s, estimated 7m 55s remaining.
# 2.6218 s (21%) simulated in 2m 0s, estimated 7m 9s remaining.
# 3.958 s (32%) simulated in 3m 0s, estimated 6m 6s remaining.
# 5.2636 s (43%) simulated in 4m 0s, estimated 5m 7s remaining.
# 6.5942 s (54%) simulated in 5m 0s, estimated 4m 6s remaining.
# 7.9681 s (66%) simulated in 6m 0s, estimated 3m 2s remaining.
# 9.24 s (77%) simulated in 7m 0s, estimated 2m 5s remaining.
# 10.5978 s (88%) simulated in 8m 0s, estimated 1m 4s remaining.
# 11.8812 s (99%) simulated in 9m 0s, estimated 5s remaining.
# 12. s (100%) simulated in 9m 5s
# 120000
# 120000
# EE 0.0322453308555247
# E_input_E 1.3289547775146695
# IE 1.6012057317655588
# global excitatory rate: <neurons_E_rate.G: array([58.9467977])>
# run  42  of  60  completed
# Starting simulation at t=0.504 ks for a duration of 12. s
# 1.3569 s (11%) simulated in 1m 0s, estimated 7m 51s remaining.
# 2.6912 s (22%) simulated in 2m 0s, estimated 6m 55s remaining.
# 4.0543 s (33%) simulated in 3m 0s, estimated 5m 53s remaining.
# 5.3746 s (44%) simulated in 4m 0s, estimated 4m 56s remaining.
# 6.732 s (56%) simulated in 5m 0s, estimated 3m 55s remaining.
# 8.0729 s (67%) simulated in 6m 0s, estimated 2m 55s remaining.
# 9.3564 s (77%) simulated in 7m 0s, estimated 1m 59s remaining.
# 10.6948 s (89%) simulated in 8m 0s, estimated 59s remaining.
# 11.9767 s (99%) simulated in 9m 0s, estimated 1s remaining.
# 12. s (100%) simulated in 9m 1s
# 120000
# 120000
# EE 0.03276799798181267
# E_input_E 1.3263268785589912
# IE 1.6175712166171956
# global excitatory rate: <neurons_E_rate.G: array([58.9819658])>
# run  43  of  60  completed
# Starting simulation at t=0.516 ks for a duration of 12. s
# 1.3734 s (11%) simulated in 1m 0s, estimated 7m 44s remaining.
# 2.6525 s (22%) simulated in 2m 0s, estimated 7m 3s remaining.
# 4.0119 s (33%) simulated in 3m 0s, estimated 5m 58s remaining.
# 5.3455 s (44%) simulated in 4m 0s, estimated 4m 59s remaining.
# 6.6543 s (55%) simulated in 5m 0s, estimated 4m 1s remaining.
# 7.9931 s (66%) simulated in 6m 0s, estimated 3m 0s remaining.
# 9.262 s (77%) simulated in 7m 0s, estimated 2m 4s remaining.
# 10.6273 s (88%) simulated in 8m 0s, estimated 1m 2s remaining.
# 12. s (100%) simulated in 8m 58s
# 120000
# 120000
# EE 0.03318149604549443
# E_input_E 1.3237397187142232
# IE 1.63372061518044
# global excitatory rate: <neurons_E_rate.G: array([59.52731717])>
# run  44  of  60  completed
# Starting simulation at t=0.528 ks for a duration of 12. s
# 1.4821 s (12%) simulated in 1m 0s, estimated 7m 6s remaining.
# 2.8089 s (23%) simulated in 2m 0s, estimated 6m 33s remaining.
# 4.2107 s (35%) simulated in 3m 0s, estimated 5m 33s remaining.
# 5.576 s (46%) simulated in 4m 0s, estimated 4m 37s remaining.
# 6.9826 s (58%) simulated in 5m 0s, estimated 3m 36s remaining.
# 8.3425 s (69%) simulated in 6m 0s, estimated 2m 38s remaining.
# 9.7627 s (81%) simulated in 7m 0s, estimated 1m 36s remaining.
# 11.2349 s (93%) simulated in 8m 0s, estimated 33s remaining.
# 12. s (100%) simulated in 8m 32s
# 120000
# 120000
# EE 0.03357969795255966
# E_input_E 1.321166775983885
# IE 1.6492812807650943
# global excitatory rate: <neurons_E_rate.G: array([59.8500339])>
# run  45  of  60  completed
# Starting simulation at t=0.54 ks for a duration of 12. s
# 1.513 s (12%) simulated in 1m 0s, estimated 6m 56s remaining.
# 2.9175 s (24%) simulated in 2m 0s, estimated 6m 14s remaining.
# 4.3582 s (36%) simulated in 3m 0s, estimated 5m 16s remaining.
# 5.7088 s (47%) simulated in 4m 0s, estimated 4m 25s remaining.
# 7.1146 s (59%) simulated in 5m 0s, estimated 3m 26s remaining.
# 8.4887 s (70%) simulated in 6m 0s, estimated 2m 29s remaining.
# 9.884 s (82%) simulated in 7m 0s, estimated 1m 30s remaining.
# 11.2715 s (93%) simulated in 8m 0s, estimated 31s remaining.
# 12. s (100%) simulated in 8m 32s
# 120000
# 120000
# EE 0.034152807137013075
# E_input_E 1.3186398289924106
# IE 1.6641724530358684
# global excitatory rate: <neurons_E_rate.G: array([60.19966042])>
# run  46  of  60  completed
# Starting simulation at t=0.552 ks for a duration of 12. s
# 1.4593 s (12%) simulated in 1m 0s, estimated 7m 13s remaining.
# 2.8256 s (23%) simulated in 2m 0s, estimated 6m 30s remaining.
# 4.3287 s (36%) simulated in 3m 0s, estimated 5m 19s remaining.
# 5.7558 s (47%) simulated in 4m 0s, estimated 4m 20s remaining.
# 7.2616 s (60%) simulated in 5m 0s, estimated 3m 16s remaining.
# 8.7092 s (72%) simulated in 6m 0s, estimated 2m 16s remaining.
# 10.2252 s (85%) simulated in 7m 0s, estimated 1m 13s remaining.
# 11.6618 s (97%) simulated in 8m 0s, estimated 14s remaining.
# 12. s (100%) simulated in 8m 14s
# 120000
# 120000
# EE 0.03444177945609335
# E_input_E 1.3161100375941626
# IE 1.6792051013080251
# global excitatory rate: <neurons_E_rate.G: array([60.21232291])>
# run  47  of  60  completed
# Starting simulation at t=0.564 ks for a duration of 12. s
# 1.4959 s (12%) simulated in 1m 0s, estimated 7m 1s remaining.
# 2.9687 s (24%) simulated in 2m 0s, estimated 6m 5s remaining.
# 4.6327 s (38%) simulated in 3m 0s, estimated 4m 46s remaining.
# 6.2011 s (51%) simulated in 4m 0s, estimated 3m 44s remaining.
# 7.8273 s (65%) simulated in 5m 0s, estimated 2m 40s remaining.
# 9.3567 s (77%) simulated in 6m 0s, estimated 1m 42s remaining.
# 11.0176 s (91%) simulated in 7m 0s, estimated 37s remaining.
# 12. s (100%) simulated in 7m 38s
# 120000
# 120000
# EE 0.035178338869141956
# E_input_E 1.3135764211525578
# IE 1.6938041083941777
# global excitatory rate: <neurons_E_rate.G: array([60.2033576])>
# run  48  of  60  completed
# Starting simulation at t=0.576 ks for a duration of 12. s
# 1.6537 s (13%) simulated in 1m 0s, estimated 6m 15s remaining.
# 3.2094 s (26%) simulated in 2m 0s, estimated 5m 29s remaining.
# 4.8881 s (40%) simulated in 3m 0s, estimated 4m 22s remaining.
# 6.5163 s (54%) simulated in 4m 0s, estimated 3m 22s remaining.
# 8.1842 s (68%) simulated in 5m 0s, estimated 2m 20s remaining.
# 9.8307 s (81%) simulated in 6m 0s, estimated 1m 19s remaining.
# 11.4641 s (95%) simulated in 7m 0s, estimated 20s remaining.
# 12. s (100%) simulated in 7m 20s
# 120000
# 120000
# EE 0.0352554986911829
# E_input_E 1.3110760590715345
# IE 1.7077108709415367
# global excitatory rate: <neurons_E_rate.G: array([60.83873958])>
# run  49  of  60  completed
# Starting simulation at t=0.588 ks for a duration of 12. s
# 1.6922 s (14%) simulated in 1m 0s, estimated 6m 6s remaining.
# 3.3191 s (27%) simulated in 2m 0s, estimated 5m 14s remaining.
# 5.0109 s (41%) simulated in 3m 0s, estimated 4m 11s remaining.
# 6.6333 s (55%) simulated in 4m 0s, estimated 3m 14s remaining.
# 8.2608 s (68%) simulated in 5m 0s, estimated 2m 16s remaining.
# 9.9206 s (82%) simulated in 6m 0s, estimated 1m 15s remaining.
# 11.5806 s (96%) simulated in 7m 0s, estimated 15s remaining.
# 12. s (100%) simulated in 7m 15s
# 120000
# 120000
# EE 0.03622257674738415
# E_input_E 1.308598051075575
# IE 1.721661345210162
# global excitatory rate: <neurons_E_rate.G: array([60.28237235])>
# run  50  of  60  completed
# Starting simulation at t=0.6 ks for a duration of 12. s
# 1.7247 s (14%) simulated in 1m 0s, estimated 5m 57s remaining.
# 3.3615 s (28%) simulated in 2m 0s, estimated 5m 8s remaining.
# 5.0658 s (42%) simulated in 3m 0s, estimated 4m 6s remaining.
# 6.7166 s (55%) simulated in 4m 0s, estimated 3m 9s remaining.
# 8.3701 s (69%) simulated in 5m 0s, estimated 2m 10s remaining.
# 10.0272 s (83%) simulated in 6m 0s, estimated 1m 11s remaining.
# 11.6286 s (96%) simulated in 7m 0s, estimated 13s remaining.
# 12. s (100%) simulated in 7m 14s
# 120000
# 120000
# EE 0.03703047898225002
# E_input_E 1.3061584514967908
# IE 1.735103448808112
# global excitatory rate: <neurons_E_rate.G: array([61.17465726])>
# run  51  of  60  completed
# Starting simulation at t=0.612 ks for a duration of 12. s
# 1.7261 s (14%) simulated in 1m 0s, estimated 5m 57s remaining.
# 3.3546 s (27%) simulated in 2m 0s, estimated 5m 9s remaining.
# 5.0478 s (42%) simulated in 3m 0s, estimated 4m 8s remaining.
# 6.6686 s (55%) simulated in 4m 0s, estimated 3m 12s remaining.
# 8.3027 s (69%) simulated in 5m 0s, estimated 2m 14s remaining.
# 9.9724 s (83%) simulated in 6m 0s, estimated 1m 13s remaining.
# 11.5809 s (96%) simulated in 7m 0s, estimated 15s remaining.
# 12. s (100%) simulated in 7m 15s
# 120000
# 120000
# EE 0.037651760722268154
# E_input_E 1.3037086921542531
# IE 1.7480986735503998
# global excitatory rate: <neurons_E_rate.G: array([61.0032088])>
# run  52  of  60  completed
# Starting simulation at t=0.624 ks for a duration of 12. s
# 1.6712 s (13%) simulated in 1m 0s, estimated 6m 11s remaining.
# 3.2423 s (27%) simulated in 2m 0s, estimated 5m 24s remaining.
# 4.9146 s (40%) simulated in 3m 0s, estimated 4m 20s remaining.
# 6.5012 s (54%) simulated in 4m 0s, estimated 3m 23s remaining.
# 8.1479 s (67%) simulated in 5m 0s, estimated 2m 22s remaining.
# 9.7771 s (81%) simulated in 6m 0s, estimated 1m 22s remaining.
# 11.417 s (95%) simulated in 7m 0s, estimated 21s remaining.
# 12. s (100%) simulated in 7m 22s
# 120000
# 120000
# EE 0.038530331662391976
# E_input_E 1.3012944274232634
# IE 1.7611770344364515
# global excitatory rate: <neurons_E_rate.G: array([61.157309])>
# run  53  of  60  completed
# Starting simulation at t=0.636 ks for a duration of 12. s
# 1.6938 s (14%) simulated in 1m 0s, estimated 6m 5s remaining.
# 3.2804 s (27%) simulated in 2m 0s, estimated 5m 19s remaining.
# 4.9455 s (41%) simulated in 3m 0s, estimated 4m 17s remaining.
# 6.5529 s (54%) simulated in 4m 0s, estimated 3m 20s remaining.
# 8.1882 s (68%) simulated in 5m 0s, estimated 2m 20s remaining.
# 9.8413 s (82%) simulated in 6m 0s, estimated 1m 19s remaining.
# 11.4981 s (95%) simulated in 7m 0s, estimated 18s remaining.
# 12. s (100%) simulated in 7m 18s
# 120000
# 120000
# EE 0.03955098627876306
# E_input_E 1.2989110314405297
# IE 1.7737754696107013
# global excitatory rate: <neurons_E_rate.G: array([61.66901564])>
# run  54  of  60  completed
# Starting simulation at t=0.648 ks for a duration of 12. s
# 1.7233 s (14%) simulated in 1m 0s, estimated 5m 58s remaining.
# 3.3448 s (27%) simulated in 2m 0s, estimated 5m 11s remaining.
# 5.0134 s (41%) simulated in 3m 0s, estimated 4m 11s remaining.
# 6.637 s (55%) simulated in 4m 0s, estimated 3m 14s remaining.
# 8.2811 s (69%) simulated in 5m 0s, estimated 2m 15s remaining.
# 9.9336 s (82%) simulated in 6m 0s, estimated 1m 15s remaining.
# 11.5484 s (96%) simulated in 7m 0s, estimated 16s remaining.
# 12. s (100%) simulated in 7m 17s
# 120000
# 120000
# EE 0.04041738616586788
# E_input_E 1.2965144527283872
# IE 1.7858862450757012
# global excitatory rate: <neurons_E_rate.G: array([61.84337747])>
# run  55  of  60  completed
# Starting simulation at t=0.66 ks for a duration of 12. s
# 1.7134 s (14%) simulated in 1m 0s, estimated 6m 0s remaining.
# 3.3565 s (27%) simulated in 2m 0s, estimated 5m 9s remaining.
# 5.0411 s (42%) simulated in 3m 0s, estimated 4m 8s remaining.
# 6.6665 s (55%) simulated in 4m 0s, estimated 3m 12s remaining.
# 8.2721 s (68%) simulated in 5m 0s, estimated 2m 15s remaining.
# 9.8668 s (82%) simulated in 6m 0s, estimated 1m 18s remaining.
# 11.5048 s (95%) simulated in 7m 0s, estimated 18s remaining.
# 12. s (100%) simulated in 7m 18s
# 120000
# 120000
# EE 0.0409622348072098
# E_input_E 1.2940857443035705
# IE 1.7983070378012078
# global excitatory rate: <neurons_E_rate.G: array([61.41622199])>
# run  56  of  60  completed
# Starting simulation at t=0.672 ks for a duration of 12. s
# 1.7199 s (14%) simulated in 1m 0s, estimated 5m 59s remaining.
# 3.329 s (27%) simulated in 2m 0s, estimated 5m 13s remaining.
# 5.0241 s (41%) simulated in 3m 0s, estimated 4m 10s remaining.
# 6.6618 s (55%) simulated in 4m 0s, estimated 3m 12s remaining.
# 8.3081 s (69%) simulated in 5m 0s, estimated 2m 13s remaining.
# 9.9494 s (82%) simulated in 6m 0s, estimated 1m 14s remaining.
# 11.5692 s (96%) simulated in 7m 0s, estimated 16s remaining.
# 12. s (100%) simulated in 7m 16s
# 120000
# 120000
# EE 0.04195791337120349
# E_input_E 1.2917398405662224
# IE 1.8102982858238135
# global excitatory rate: <neurons_E_rate.G: array([61.66612119])>
# run  57  of  60  completed
# Starting simulation at t=0.684 ks for a duration of 12. s
# 1.6805 s (14%) simulated in 1m 0s, estimated 6m 8s remaining.
# 3.2957 s (27%) simulated in 2m 0s, estimated 5m 17s remaining.
# 4.9833 s (41%) simulated in 3m 0s, estimated 4m 13s remaining.
# 6.5992 s (54%) simulated in 4m 0s, estimated 3m 16s remaining.
# 8.2568 s (68%) simulated in 5m 0s, estimated 2m 16s remaining.
# 9.9289 s (82%) simulated in 6m 0s, estimated 1m 15s remaining.
# 11.5667 s (96%) simulated in 7m 0s, estimated 16s remaining.
# 12. s (100%) simulated in 7m 16s
# 120000
# 120000
# EE 0.04282275496048898
# E_input_E 1.2893255788293931
# IE 1.822291510935429
# global excitatory rate: <neurons_E_rate.G: array([61.74935413])>
# run  58  of  60  completed
# Starting simulation at t=0.696 ks for a duration of 12. s
# 1.6589 s (13%) simulated in 1m 0s, estimated 6m 14s remaining.
# 3.2429 s (27%) simulated in 2m 0s, estimated 5m 24s remaining.
# 4.9171 s (40%) simulated in 3m 0s, estimated 4m 19s remaining.
# 6.5039 s (54%) simulated in 4m 0s, estimated 3m 23s remaining.
# 8.1333 s (67%) simulated in 5m 0s, estimated 2m 23s remaining.
# 9.757 s (81%) simulated in 6m 0s, estimated 1m 23s remaining.
# 11.3639 s (94%) simulated in 7m 0s, estimated 24s remaining.
# 12. s (100%) simulated in 7m 24s
# 120000
# 120000
# EE 0.04383794389500319
# E_input_E 1.2869975829238989
# IE 1.8338284437497383
# global excitatory rate: <neurons_E_rate.G: array([61.90682884])>
# run  59  of  60  completed
# Starting simulation at t=0.708 ks for a duration of 12. s
# 1.6713 s (13%) simulated in 1m 0s, estimated 6m 11s remaining.
# 3.2324 s (26%) simulated in 2m 0s, estimated 5m 25s remaining.
# 4.8761 s (40%) simulated in 3m 0s, estimated 4m 23s remaining.
# 6.4508 s (53%) simulated in 4m 0s, estimated 3m 26s remaining.
# 8.0755 s (67%) simulated in 5m 0s, estimated 2m 26s remaining.
# 9.6568 s (80%) simulated in 6m 0s, estimated 1m 27s remaining.
# 11.2725 s (93%) simulated in 7m 0s, estimated 27s remaining.
# 12. s (100%) simulated in 7m 28s
# 120000
# 120000
# EE 0.045033178803759975
# E_input_E 1.2846661393638896
# IE 1.8454844011583105
# global excitatory rate: <neurons_E_rate.G: array([61.94401851])>
# run  60  of  60  completed
# saving data
# saving data
