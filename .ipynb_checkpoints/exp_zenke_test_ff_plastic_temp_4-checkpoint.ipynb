# %%
import networks_3
import equations
import matplotlib.pyplot as plt
from brian2 import *
import imp
reload(equations)
reload(networks_3)
# Out:
# <module 'networks_3' from 'networks_3.pyc'>

# %%
neurons={'E_rate':{'t_H':2000*ms,'gamma':4.}}
trial_id = None
w_IE_init=0.2
w_FE_init=.4
reinit_W=False

# %%
exp = networks_3.exp_zenke_test_ff_plastic()

# %%
exp.run(neurons=neurons, trial_id=trial_id, w_IE_init=w_IE_init, w_FE_init=w_FE_init, reinit_W=reinit_W)
# Out:
# {'rec_variables': [], 't_H': 2. * second, 'gamma': 4.0, 'N': 1}
# Starting simulation at t=0. s for a duration of 12. s
# 2.1592 s (17%) simulated in 1m 0s, estimated 4m 33s remaining.
# 4.3397 s (36%) simulated in 2m 0s, estimated 3m 32s remaining.
# 6.4367 s (53%) simulated in 3m 0s, estimated 2m 36s remaining.
# 8.4426 s (70%) simulated in 4m 0s, estimated 1m 41s remaining.
# 10.4366 s (86%) simulated in 5m 0s, estimated 45s remaining.
# 12. s (100%) simulated in 5m 46s
# 120000
# 120000
# EE 0.10000000000000012
# E_input_E 0.39999999999999936
# IE 0.19999999999999996
# global excitatory rate: <neurons_E_rate.G: array([41.63690119])>
# run  1  of  60  completed
# Starting simulation at t=12. s for a duration of 12. s
# 1.9885 s (16%) simulated in 1m 0s, estimated 5m 2s remaining.
# 3.963 s (33%) simulated in 2m 0s, estimated 4m 3s remaining.
# 5.9303 s (49%) simulated in 3m 0s, estimated 3m 4s remaining.
# 7.869 s (65%) simulated in 4m 0s, estimated 2m 6s remaining.
# 9.8264 s (81%) simulated in 5m 0s, estimated 1m 6s remaining.
# 11.8107 s (98%) simulated in 6m 0s, estimated 6s remaining.
# 12. s (100%) simulated in 6m 5s
# 120000
# 120000
# EE 0.10000000000000012
# E_input_E 0.39999999999999936
# IE 0.19999999999999996
# global excitatory rate: <neurons_E_rate.G: array([41.56617481])>
# run  2  of  60  completed
# Starting simulation at t=24. s for a duration of 12. s
# 2.0475 s (17%) simulated in 1m 0s, estimated 4m 52s remaining.
# 4.2614 s (35%) simulated in 2m 0s, estimated 3m 38s remaining.
# 6.6146 s (55%) simulated in 3m 0s, estimated 2m 27s remaining.
# 9.1586 s (76%) simulated in 4m 0s, estimated 1m 14s remaining.
# 11.8256 s (98%) simulated in 5m 0s, estimated 4s remaining.
# 12. s (100%) simulated in 5m 4s
# 120000
# 120000
# EE 0.07912964457446983
# E_input_E 0.42236907455863826
# IE 0.24111782330096512
# global excitatory rate: <neurons_E_rate.G: array([17.37152402])>
# run  3  of  60  completed
# Starting simulation at t=36. s for a duration of 12. s
# 2.725 s (22%) simulated in 1m 0s, estimated 3m 24s remaining.
# 5.4478 s (45%) simulated in 2m 0s, estimated 2m 24s remaining.
# 8.2143 s (68%) simulated in 3m 0s, estimated 1m 23s remaining.
# 10.9328 s (91%) simulated in 4m 0s, estimated 23s remaining.
# 12. s (100%) simulated in 4m 23s
# 120000
# 120000
# EE 0.06646426058295642
# E_input_E 0.426334759386265
# IE 0.25701457590997484
# global excitatory rate: <neurons_E_rate.G: array([12.04655727])>
# run  4  of  60  completed
# Starting simulation at t=48. s for a duration of 12. s
# 2.6846 s (22%) simulated in 1m 0s, estimated 3m 28s remaining.
# 5.4213 s (45%) simulated in 2m 0s, estimated 2m 26s remaining.
# 8.2019 s (68%) simulated in 3m 0s, estimated 1m 23s remaining.
# 10.9616 s (91%) simulated in 4m 0s, estimated 23s remaining.
# 12. s (100%) simulated in 4m 22s
# 120000
# 120000
# EE 0.058806753229597025
# E_input_E 0.44441537548083343
# IE 0.2692967203852903
# global excitatory rate: <neurons_E_rate.G: array([12.45087963])>
# run  5  of  60  completed
# Starting simulation at t=60. s for a duration of 12. s
# 2.7849 s (23%) simulated in 1m 0s, estimated 3m 19s remaining.
# 5.4106 s (45%) simulated in 2m 0s, estimated 2m 26s remaining.
# 8.0528 s (67%) simulated in 3m 0s, estimated 1m 28s remaining.
# 10.6629 s (88%) simulated in 4m 0s, estimated 30s remaining.
# 12. s (100%) simulated in 4m 30s
# 120000
# 120000
# EE 0.053346120666116055
# E_input_E 0.48107754506743433
# IE 0.2828756520739606
# global excitatory rate: <neurons_E_rate.G: array([15.65991976])>
# run  6  of  60  completed
# Starting simulation at t=72. s for a duration of 12. s
# 2.5608 s (21%) simulated in 1m 0s, estimated 3m 41s remaining.
# 5.1792 s (43%) simulated in 2m 0s, estimated 2m 38s remaining.
# 7.6901 s (64%) simulated in 3m 0s, estimated 1m 41s remaining.
# 10.1521 s (84%) simulated in 4m 0s, estimated 44s remaining.
# 12. s (100%) simulated in 4m 45s
# 120000
# 120000
# EE 0.04914521778135338
# E_input_E 0.5446939360782905
# IE 0.30069820788837726
# global excitatory rate: <neurons_E_rate.G: array([21.69763174])>
# run  7  of  60  completed
# Starting simulation at t=84. s for a duration of 12. s
# 2.2847 s (19%) simulated in 1m 0s, estimated 4m 15s remaining.
# 4.518 s (37%) simulated in 2m 0s, estimated 3m 19s remaining.
# 6.6655 s (55%) simulated in 3m 0s, estimated 2m 24s remaining.
# 8.7764 s (73%) simulated in 4m 0s, estimated 1m 28s remaining.
# 10.9645 s (91%) simulated in 5m 0s, estimated 28s remaining.
# 12. s (100%) simulated in 5m 32s
# 120000
# 120000
# EE 0.04560636969178101
# E_input_E 0.649760962270124
# IE 0.3253116205769082
# global excitatory rate: <neurons_E_rate.G: array([30.78180942])>
# run  8  of  60  completed
# Starting simulation at t=96. s for a duration of 12. s
# 2.0564 s (17%) simulated in 1m 0s, estimated 4m 50s remaining.
# 3.988 s (33%) simulated in 2m 0s, estimated 4m 1s remaining.
# 5.9065 s (49%) simulated in 3m 0s, estimated 3m 6s remaining.
# 7.9023 s (65%) simulated in 4m 0s, estimated 2m 4s remaining.
# 9.7785 s (81%) simulated in 5m 0s, estimated 1m 8s remaining.
# 11.6764 s (97%) simulated in 6m 0s, estimated 10s remaining.
# 12. s (100%) simulated in 6m 10s
# 120000
# 120000
# EE 0.04285988148288403
# E_input_E 0.7321773008538672
# IE 0.35902799956595244
# global excitatory rate: <neurons_E_rate.G: array([38.34158901])>
# run  9  of  60  completed
# Starting simulation at t=108. s for a duration of 12. s
# 1.9591 s (16%) simulated in 1m 0s, estimated 5m 8s remaining.
# 3.7717 s (31%) simulated in 2m 0s, estimated 4m 22s remaining.
# 5.591 s (46%) simulated in 3m 0s, estimated 3m 26s remaining.
# 7.4667 s (62%) simulated in 4m 0s, estimated 2m 26s remaining.
# 9.2484 s (77%) simulated in 5m 0s, estimated 1m 29s remaining.
# 11.1343 s (92%) simulated in 6m 0s, estimated 28s remaining.
# 12. s (100%) simulated in 6m 29s
# 120000
# 120000
# EE 0.04060797265118086
# E_input_E 0.793390474883157
# IE 0.3982265867857865
# global excitatory rate: <neurons_E_rate.G: array([43.36104716])>
# run  10  of  60  completed
# Starting simulation at t=120. s for a duration of 12. s
# 1.91 s (15%) simulated in 1m 0s, estimated 5m 17s remaining.
# 3.6864 s (30%) simulated in 2m 0s, estimated 4m 31s remaining.
# 5.4855 s (45%) simulated in 3m 0s, estimated 3m 34s remaining.
# 7.3058 s (60%) simulated in 4m 0s, estimated 2m 34s remaining.
# 9.035 s (75%) simulated in 5m 0s, estimated 1m 38s remaining.
# 10.9417 s (91%) simulated in 6m 0s, estimated 35s remaining.
# 12. s (100%) simulated in 6m 36s
# 120000
# 120000
# EE 0.03894782270041567
# E_input_E 0.8237882121257909
# IE 0.43906469013957117
# global excitatory rate: <neurons_E_rate.G: array([45.36193567])>
# run  11  of  60  completed
# Starting simulation at t=132. s for a duration of 12. s
# 1.9028 s (15%) simulated in 1m 0s, estimated 5m 18s remaining.
# 3.6634 s (30%) simulated in 2m 0s, estimated 4m 33s remaining.
# 5.4648 s (45%) simulated in 3m 0s, estimated 3m 35s remaining.
# 7.26 s (60%) simulated in 4m 0s, estimated 2m 37s remaining.
# 9.0001 s (75%) simulated in 5m 0s, estimated 1m 40s remaining.
# 10.8699 s (90%) simulated in 6m 0s, estimated 37s remaining.
# 12. s (100%) simulated in 6m 39s
# 120000
# 120000
# EE 0.03754167488788513
# E_input_E 0.8470644762797361
# IE 0.47932969971648004
# global excitatory rate: <neurons_E_rate.G: array([46.42459028])>
# run  12  of  60  completed
# Starting simulation at t=144. s for a duration of 12. s
# 1.8427 s (15%) simulated in 1m 0s, estimated 5m 31s remaining.
# 3.6376 s (30%) simulated in 2m 0s, estimated 4m 36s remaining.
# 5.4145 s (45%) simulated in 3m 0s, estimated 3m 39s remaining.
# 7.1848 s (59%) simulated in 4m 0s, estimated 2m 41s remaining.
# 8.9162 s (74%) simulated in 5m 0s, estimated 1m 44s remaining.
# 10.7974 s (89%) simulated in 6m 0s, estimated 40s remaining.
# 12. s (100%) simulated in 6m 42s
# 120000
# 120000
# EE 0.036563491674951556
# E_input_E 0.8534431687433062
# IE 0.5172392501846884
# global excitatory rate: <neurons_E_rate.G: array([46.14418035])>
# run  13  of  60  completed
# Starting simulation at t=156. s for a duration of 12. s
# 1.8641 s (15%) simulated in 1m 0s, estimated 5m 26s remaining.
# 3.6285 s (30%) simulated in 2m 0s, estimated 4m 37s remaining.
# 5.449 s (45%) simulated in 3m 0s, estimated 3m 36s remaining.
# 7.2906 s (60%) simulated in 4m 0s, estimated 2m 35s remaining.
# 9.0641 s (75%) simulated in 5m 0s, estimated 1m 37s remaining.
# 10.937 s (91%) simulated in 6m 0s, estimated 35s remaining.
# 12. s (100%) simulated in 6m 37s
# 120000
# 120000
# EE 0.03560333368783094
# E_input_E 0.8548646987988384
# IE 0.5525964608524901
# global excitatory rate: <neurons_E_rate.G: array([45.47716408])>
# run  14  of  60  completed
# Starting simulation at t=168. s for a duration of 12. s
# 1.8615 s (15%) simulated in 1m 0s, estimated 5m 27s remaining.
# 3.6581 s (30%) simulated in 2m 0s, estimated 4m 34s remaining.
# 5.4573 s (45%) simulated in 3m 0s, estimated 3m 36s remaining.
# 7.2818 s (60%) simulated in 4m 0s, estimated 2m 36s remaining.
# 9.0984 s (75%) simulated in 5m 0s, estimated 1m 36s remaining.
# 11.0363 s (91%) simulated in 6m 0s, estimated 31s remaining.
# 12. s (100%) simulated in 6m 32s
# 120000
# 120000
# EE 0.03484767284418896
# E_input_E 0.8576694742631453
# IE 0.5855925226722749
# global excitatory rate: <neurons_E_rate.G: array([45.45439764])>
# run  15  of  60  completed
# Starting simulation at t=180. s for a duration of 12. s
# 1.8903 s (15%) simulated in 1m 0s, estimated 5m 21s remaining.
# 3.6742 s (30%) simulated in 2m 0s, estimated 4m 32s remaining.
# 5.4668 s (45%) simulated in 3m 0s, estimated 3m 35s remaining.
# 7.2996 s (60%) simulated in 4m 0s, estimated 2m 35s remaining.
# 9.0289 s (75%) simulated in 5m 0s, estimated 1m 39s remaining.
# 10.9407 s (91%) simulated in 6m 0s, estimated 35s remaining.
# 12. s (100%) simulated in 6m 37s
# 120000
# 120000
# EE 0.034132354431297945
# E_input_E 0.8577486526494993
# IE 0.6168624227223236
# global excitatory rate: <neurons_E_rate.G: array([45.18814863])>
# run  16  of  60  completed
# Starting simulation at t=192. s for a duration of 12. s
# 1.9006 s (15%) simulated in 1m 0s, estimated 5m 19s remaining.
# 3.6728 s (30%) simulated in 2m 0s, estimated 4m 32s remaining.
# 5.4811 s (45%) simulated in 3m 0s, estimated 3m 34s remaining.
# 7.2798 s (60%) simulated in 4m 0s, estimated 2m 36s remaining.
# 9.0259 s (75%) simulated in 5m 0s, estimated 1m 39s remaining.
# 10.8835 s (90%) simulated in 6m 0s, estimated 37s remaining.
# 12. s (100%) simulated in 6m 39s
# 120000
# 120000
# EE 0.033484783616474556
# E_input_E 0.8536429423265932
# IE 0.6465044636441106
# global excitatory rate: <neurons_E_rate.G: array([44.68017786])>
# run  17  of  60  completed
# Starting simulation at t=204. s for a duration of 12. s
# 1.9205 s (16%) simulated in 1m 0s, estimated 5m 15s remaining.
# 3.6782 s (30%) simulated in 2m 0s, estimated 4m 32s remaining.
# 5.4604 s (45%) simulated in 3m 0s, estimated 3m 36s remaining.
# 7.2906 s (60%) simulated in 4m 0s, estimated 2m 35s remaining.
# 9.0215 s (75%) simulated in 5m 0s, estimated 1m 39s remaining.
# 10.9137 s (90%) simulated in 6m 0s, estimated 36s remaining.
# 12. s (100%) simulated in 6m 37s
# 120000
# 120000
# EE 0.03293088136190317
# E_input_E 0.8515554631041551
# IE 0.6743454982068303
# global excitatory rate: <neurons_E_rate.G: array([44.53366012])>
# run  18  of  60  completed
# Starting simulation at t=216. s for a duration of 12. s
# 1.9263 s (16%) simulated in 1m 0s, estimated 5m 14s remaining.
# 3.7782 s (31%) simulated in 2m 0s, estimated 4m 21s remaining.
# 5.6156 s (46%) simulated in 3m 0s, estimated 3m 25s remaining.
# 7.4675 s (62%) simulated in 4m 0s, estimated 2m 26s remaining.
# 9.2333 s (76%) simulated in 5m 0s, estimated 1m 30s remaining.
# 11.1152 s (92%) simulated in 6m 0s, estimated 29s remaining.
# 12. s (100%) simulated in 6m 31s
# 120000
# 120000
# EE 0.03243668794751087
# E_input_E 0.847733935575276
# IE 0.7005157806011519
# global excitatory rate: <neurons_E_rate.G: array([44.08207418])>
# run  19  of  60  completed
# Starting simulation at t=228. s for a duration of 12. s
# 1.8891 s (15%) simulated in 1m 0s, estimated 5m 21s remaining.
# 3.6461 s (30%) simulated in 2m 0s, estimated 4m 35s remaining.
# 5.4814 s (45%) simulated in 3m 0s, estimated 3m 34s remaining.
# 7.3211 s (61%) simulated in 4m 0s, estimated 2m 33s remaining.
# 9.0666 s (75%) simulated in 5m 0s, estimated 1m 37s remaining.
# 10.9456 s (91%) simulated in 6m 0s, estimated 35s remaining.
# 12. s (100%) simulated in 6m 36s
# 120000
# 120000
# EE 0.03196727476435161
# E_input_E 0.8430983589450505
# IE 0.7255781891873517
# global excitatory rate: <neurons_E_rate.G: array([43.86516865])>
# run  20  of  60  completed
# Starting simulation at t=240. s for a duration of 12. s
# 1.9185 s (15%) simulated in 1m 0s, estimated 5m 15s remaining.
# 3.7437 s (31%) simulated in 2m 0s, estimated 4m 25s remaining.
# 5.5554 s (46%) simulated in 3m 0s, estimated 3m 29s remaining.
# 7.4207 s (61%) simulated in 4m 0s, estimated 2m 28s remaining.
# 9.1953 s (76%) simulated in 5m 0s, estimated 1m 32s remaining.
# 11.061 s (92%) simulated in 6m 0s, estimated 31s remaining.
# 12. s (100%) simulated in 6m 32s
# 120000
# 120000
# EE 0.03149778641760673
# E_input_E 0.8395648623524256
# IE 0.7494483707276055
# global excitatory rate: <neurons_E_rate.G: array([43.67115105])>
# run  21  of  60  completed
# Starting simulation at t=252. s for a duration of 12. s
# 1.8884 s (15%) simulated in 1m 0s, estimated 5m 21s remaining.
# 3.6914 s (30%) simulated in 2m 0s, estimated 4m 30s remaining.
# 5.5333 s (46%) simulated in 3m 0s, estimated 3m 30s remaining.
# 7.3654 s (61%) simulated in 4m 0s, estimated 2m 31s remaining.
# 9.1422 s (76%) simulated in 5m 0s, estimated 1m 34s remaining.
# 11.0518 s (92%) simulated in 6m 0s, estimated 31s remaining.
# 12. s (100%) simulated in 6m 32s
# 120000
# 120000
# EE 0.031123550066286514
# E_input_E 0.8361544246524795
# IE 0.772268296925224
# global excitatory rate: <neurons_E_rate.G: array([43.84974859])>
# run  22  of  60  completed
# Starting simulation at t=264. s for a duration of 12. s
# 1.937 s (16%) simulated in 1m 0s, estimated 5m 12s remaining.
# 3.7347 s (31%) simulated in 2m 0s, estimated 4m 26s remaining.
# 5.565 s (46%) simulated in 3m 0s, estimated 3m 28s remaining.
# 7.4336 s (61%) simulated in 4m 0s, estimated 2m 27s remaining.
# 9.1955 s (76%) simulated in 5m 0s, estimated 1m 32s remaining.
# 11.0664 s (92%) simulated in 6m 0s, estimated 30s remaining.
# 12. s (100%) simulated in 6m 32s
# 120000
# 120000
# EE 0.030722193119878047
# E_input_E 0.8334830188023197
# IE 0.7944147135522442
# global excitatory rate: <neurons_E_rate.G: array([43.88411121])>
# run  23  of  60  completed
# Starting simulation at t=276. s for a duration of 12. s
# 1.9334 s (16%) simulated in 1m 0s, estimated 5m 12s remaining.
# 3.7174 s (30%) simulated in 2m 0s, estimated 4m 27s remaining.
# 5.5985 s (46%) simulated in 3m 0s, estimated 3m 26s remaining.
# 7.483 s (62%) simulated in 4m 0s, estimated 2m 25s remaining.
# 9.2752 s (77%) simulated in 5m 0s, estimated 1m 28s remaining.
# 11.15 s (92%) simulated in 6m 0s, estimated 27s remaining.
# 12. s (100%) simulated in 6m 28s
# 120000
# 120000
# EE 0.03043577699267336
# E_input_E 0.8290826313555634
# IE 0.8155312867648196
# global excitatory rate: <neurons_E_rate.G: array([43.8743282])>
# run  24  of  60  completed
# Starting simulation at t=288. s for a duration of 12. s
# 1.8931 s (15%) simulated in 1m 0s, estimated 5m 20s remaining.
# 3.6611 s (30%) simulated in 2m 0s, estimated 4m 33s remaining.
# 5.5022 s (45%) simulated in 3m 0s, estimated 3m 33s remaining.
# 7.3544 s (61%) simulated in 4m 0s, estimated 2m 32s remaining.
# 9.1139 s (75%) simulated in 5m 0s, estimated 1m 35s remaining.
# 11.0168 s (91%) simulated in 6m 0s, estimated 32s remaining.
# 12. s (100%) simulated in 6m 34s
# 120000
# 120000
# EE 0.030068095799117404
# E_input_E 0.8255791542275125
# IE 0.8356424217503722
# global excitatory rate: <neurons_E_rate.G: array([43.74907862])>
# run  25  of  60  completed
# Starting simulation at t=300. s for a duration of 12. s
# 1.8401 s (15%) simulated in 1m 0s, estimated 5m 31s remaining.
# 3.6113 s (30%) simulated in 2m 0s, estimated 4m 39s remaining.
# 5.4213 s (45%) simulated in 3m 0s, estimated 3m 38s remaining.
# 7.2534 s (60%) simulated in 4m 0s, estimated 2m 37s remaining.
# 9.0157 s (75%) simulated in 5m 0s, estimated 1m 39s remaining.
# 10.9049 s (90%) simulated in 6m 0s, estimated 36s remaining.
# 12. s (100%) simulated in 6m 38s
# 120000
# 120000
# EE 0.029838650703086566
# E_input_E 0.8212036081809029
# IE 0.8551721635909015
# global excitatory rate: <neurons_E_rate.G: array([44.20344302])>
# run  26  of  60  completed
# Starting simulation at t=312. s for a duration of 12. s
# 1.8801 s (15%) simulated in 1m 0s, estimated 5m 23s remaining.
# 3.6439 s (30%) simulated in 2m 0s, estimated 4m 35s remaining.
# 5.4418 s (45%) simulated in 3m 0s, estimated 3m 37s remaining.
# 7.2613 s (60%) simulated in 4m 0s, estimated 2m 37s remaining.
# 9.0075 s (75%) simulated in 5m 0s, estimated 1m 40s remaining.
# 10.9203 s (91%) simulated in 6m 0s, estimated 36s remaining.
# 12. s (100%) simulated in 6m 37s
# 120000
# 120000
# EE 0.029561072772962417
# E_input_E 0.8168417712044826
# IE 0.8738368009792963
# global excitatory rate: <neurons_E_rate.G: array([44.22959141])>
# run  27  of  60  completed
# Starting simulation at t=0.324 ks for a duration of 12. s
# 1.8817 s (15%) simulated in 1m 0s, estimated 5m 23s remaining.
# 3.6919 s (30%) simulated in 2m 0s, estimated 4m 30s remaining.
# 5.5057 s (45%) simulated in 3m 0s, estimated 3m 32s remaining.
# 7.3513 s (61%) simulated in 4m 0s, estimated 2m 32s remaining.
# 9.1201 s (76%) simulated in 5m 0s, estimated 1m 35s remaining.
# 11.0229 s (91%) simulated in 6m 0s, estimated 32s remaining.
# 12. s (100%) simulated in 6m 33s
# 120000
# 120000
# EE 0.029334722866154895
# E_input_E 0.8125640836570793
# IE 0.8916375060790065
# global excitatory rate: <neurons_E_rate.G: array([44.47793259])>
# run  28  of  60  completed
# Starting simulation at t=0.336 ks for a duration of 12. s
# 1.9029 s (15%) simulated in 1m 0s, estimated 5m 18s remaining.
# 3.6564 s (30%) simulated in 2m 0s, estimated 4m 34s remaining.
# 5.4578 s (45%) simulated in 3m 0s, estimated 3m 36s remaining.
# 7.3738 s (61%) simulated in 4m 0s, estimated 2m 31s remaining.
# 9.2386 s (76%) simulated in 5m 0s, estimated 1m 30s remaining.
# 11.1973 s (93%) simulated in 6m 0s, estimated 26s remaining.
# 12. s (100%) simulated in 6m 27s
# 120000
# 120000
# EE 0.029131291579663973
# E_input_E 0.8083310287744949
# IE 0.9089652881287936
# global excitatory rate: <neurons_E_rate.G: array([44.40220978])>
# run  29  of  60  completed
# Starting simulation at t=0.348 ks for a duration of 12. s
# 1.9148 s (15%) simulated in 1m 0s, estimated 5m 16s remaining.
# 3.7213 s (31%) simulated in 2m 0s, estimated 4m 27s remaining.
# 5.5553 s (46%) simulated in 3m 0s, estimated 3m 29s remaining.
# 7.3743 s (61%) simulated in 4m 0s, estimated 2m 31s remaining.
# 9.1346 s (76%) simulated in 5m 0s, estimated 1m 34s remaining.
# 11.0002 s (91%) simulated in 6m 0s, estimated 33s remaining.
# 12. s (100%) simulated in 6m 35s
# 120000
# 120000
# EE 0.02895410040431486
# E_input_E 0.8041452525622462
# IE 0.925568472938085
# global excitatory rate: <neurons_E_rate.G: array([44.47491233])>
# run  30  of  60  completed
# Starting simulation at t=0.36 ks for a duration of 12. s
# 1.8673 s (15%) simulated in 1m 0s, estimated 5m 26s remaining.
# 3.6494 s (30%) simulated in 2m 0s, estimated 4m 35s remaining.
# 5.4691 s (45%) simulated in 3m 0s, estimated 3m 35s remaining.
# 7.3283 s (61%) simulated in 4m 0s, estimated 2m 33s remaining.
# 9.0465 s (75%) simulated in 5m 0s, estimated 1m 38s remaining.
# 10.9219 s (91%) simulated in 6m 0s, estimated 36s remaining.
# 12. s (100%) simulated in 6m 38s
# 120000
# 120000
# EE 0.02869893601255168
# E_input_E 0.79998693406699
# IE 0.9414784065914809
# global excitatory rate: <neurons_E_rate.G: array([44.64322297])>
# run  31  of  60  completed
# Starting simulation at t=0.372 ks for a duration of 12. s
# 1.8686 s (15%) simulated in 1m 0s, estimated 5m 25s remaining.
# 3.6274 s (30%) simulated in 2m 0s, estimated 4m 37s remaining.
# 5.4224 s (45%) simulated in 3m 0s, estimated 3m 38s remaining.
# 7.2258 s (60%) simulated in 4m 0s, estimated 2m 39s remaining.
# 8.9574 s (74%) simulated in 5m 0s, estimated 1m 42s remaining.
# 10.8425 s (90%) simulated in 6m 0s, estimated 38s remaining.
# 12. s (100%) simulated in 6m 40s
# 120000
# 120000
# EE 0.02853496786748908
# E_input_E 0.7958906324745656
# IE 0.9570036610370722
# global excitatory rate: <neurons_E_rate.G: array([44.70479506])>
# run  32  of  60  completed
# Starting simulation at t=0.384 ks for a duration of 12. s
# 1.9101 s (15%) simulated in 1m 0s, estimated 5m 17s remaining.
# 3.7161 s (30%) simulated in 2m 0s, estimated 4m 28s remaining.
# 5.5384 s (46%) simulated in 3m 0s, estimated 3m 30s remaining.
# 7.4044 s (61%) simulated in 4m 0s, estimated 2m 29s remaining.
# 9.1399 s (76%) simulated in 5m 0s, estimated 1m 34s remaining.
# 10.9924 s (91%) simulated in 6m 0s, estimated 33s remaining.
# 12. s (100%) simulated in 6m 36s
# 120000
# 120000
# EE 0.02839325969466881
# E_input_E 0.7918498733072122
# IE 0.9718425581637713
# global excitatory rate: <neurons_E_rate.G: array([44.90159656])>
# run  33  of  60  completed
# Starting simulation at t=0.396 ks for a duration of 12. s
# 1.8878 s (15%) simulated in 1m 0s, estimated 5m 21s remaining.
# 3.6656 s (30%) simulated in 2m 0s, estimated 4m 33s remaining.
# 5.4864 s (45%) simulated in 3m 0s, estimated 3m 34s remaining.
# 7.3468 s (61%) simulated in 4m 0s, estimated 2m 32s remaining.
# 9.0995 s (75%) simulated in 5m 0s, estimated 1m 36s remaining.
# 10.9892 s (91%) simulated in 6m 0s, estimated 33s remaining.
# 12. s (100%) simulated in 6m 35s
# 120000
# 120000
# EE 0.028330805684028876
# E_input_E 0.7878510975214437
# IE 0.9862074576038563
# global excitatory rate: <neurons_E_rate.G: array([45.55246733])>
# run  34  of  60  completed
# Starting simulation at t=0.408 ks for a duration of 12. s
# 1.9112 s (15%) simulated in 1m 0s, estimated 5m 17s remaining.
# 3.6983 s (30%) simulated in 2m 0s, estimated 4m 29s remaining.
# 5.5262 s (46%) simulated in 3m 0s, estimated 3m 31s remaining.
# 7.4239 s (61%) simulated in 4m 0s, estimated 2m 28s remaining.
# 9.1967 s (76%) simulated in 5m 0s, estimated 1m 31s remaining.
# 11.0721 s (92%) simulated in 6m 0s, estimated 30s remaining.
# 12. s (100%) simulated in 6m 32s
# 120000
# 120000
# EE 0.028090081629173674
# E_input_E 0.7838872272230891
# IE 1.0001669114336151
# global excitatory rate: <neurons_E_rate.G: array([45.49502276])>
# run  35  of  60  completed
# Starting simulation at t=0.42 ks for a duration of 12. s
# 1.8624 s (15%) simulated in 1m 0s, estimated 5m 27s remaining.
# 3.5407 s (29%) simulated in 2m 0s, estimated 4m 47s remaining.
# 5.3542 s (44%) simulated in 3m 0s, estimated 3m 43s remaining.
# 7.1692 s (59%) simulated in 4m 0s, estimated 2m 42s remaining.
# 8.9571 s (74%) simulated in 5m 0s, estimated 1m 42s remaining.
# 10.8763 s (90%) simulated in 6m 0s, estimated 37s remaining.
# 12. s (100%) simulated in 6m 39s
# 120000
# 120000
# EE 0.02802110401539368
# E_input_E 0.7799530551708578
# IE 1.0137664329986749
# global excitatory rate: <neurons_E_rate.G: array([45.73169486])>
# run  36  of  60  completed
# Starting simulation at t=0.432 ks for a duration of 12. s
# 1.8555 s (15%) simulated in 1m 0s, estimated 5m 28s remaining.
# 3.5831 s (29%) simulated in 2m 0s, estimated 4m 42s remaining.
# 5.3539 s (44%) simulated in 3m 0s, estimated 3m 43s remaining.
# 7.1762 s (59%) simulated in 4m 0s, estimated 2m 41s remaining.
# 8.9194 s (74%) simulated in 5m 0s, estimated 1m 44s remaining.
# 10.7801 s (89%) simulated in 6m 0s, estimated 41s remaining.
# 12. s (100%) simulated in 6m 42s
# 120000
# 120000
# EE 0.027958076695386778
# E_input_E 0.7760428467404203
# IE 1.0267165722468712
# global excitatory rate: <neurons_E_rate.G: array([46.005394])>
# run  37  of  60  completed
# Starting simulation at t=0.444 ks for a duration of 12. s
# 1.8242 s (15%) simulated in 1m 0s, estimated 5m 35s remaining.
# 3.5261 s (29%) simulated in 2m 0s, estimated 4m 48s remaining.
# 5.3089 s (44%) simulated in 3m 0s, estimated 3m 47s remaining.
# 7.1876 s (59%) simulated in 4m 0s, estimated 2m 41s remaining.
# 8.9292 s (74%) simulated in 5m 0s, estimated 1m 43s remaining.
# 10.7968 s (89%) simulated in 6m 0s, estimated 40s remaining.
# 12. s (100%) simulated in 6m 42s
# 120000
# 120000
# EE 0.027781599154654082
# E_input_E 0.7720944403066015
# IE 1.0451430084110809
# global excitatory rate: <neurons_E_rate.G: array([46.05234975])>
# run  38  of  60  completed
# Starting simulation at t=0.456 ks for a duration of 12. s
# 1.8171 s (15%) simulated in 1m 0s, estimated 5m 36s remaining.
# 3.534 s (29%) simulated in 2m 0s, estimated 4m 48s remaining.
# 5.3252 s (44%) simulated in 3m 0s, estimated 3m 46s remaining.
# 7.1097 s (59%) simulated in 4m 0s, estimated 2m 45s remaining.
# 8.8499 s (73%) simulated in 5m 0s, estimated 1m 47s remaining.
# 10.6793 s (88%) simulated in 6m 0s, estimated 45s remaining.
# 12. s (100%) simulated in 6m 45s
# 120000
# 120000
# EE 0.027593419477948224
# E_input_E 0.768290953102674
# IE 1.0573223112092789
# global excitatory rate: <neurons_E_rate.G: array([46.88355728])>
# run  39  of  60  completed
# Starting simulation at t=0.468 ks for a duration of 12. s
# 1.8266 s (15%) simulated in 1m 0s, estimated 5m 34s remaining.
# 3.5411 s (29%) simulated in 2m 0s, estimated 4m 47s remaining.
# 5.3208 s (44%) simulated in 3m 0s, estimated 3m 46s remaining.
# 7.0758 s (58%) simulated in 4m 0s, estimated 2m 47s remaining.
# 8.8024 s (73%) simulated in 5m 0s, estimated 1m 49s remaining.
# 10.6355 s (88%) simulated in 6m 0s, estimated 46s remaining.
# 12. s (100%) simulated in 6m 47s
# 120000
# 120000
# EE 0.02763795918445117
# E_input_E 0.7645623859701891
# IE 1.0689288156198253
# global excitatory rate: <neurons_E_rate.G: array([47.00555939])>
# run  40  of  60  completed
# Starting simulation at t=0.48 ks for a duration of 12. s
# 1.8177 s (15%) simulated in 1m 0s, estimated 5m 36s remaining.
# 3.5497 s (29%) simulated in 2m 0s, estimated 4m 46s remaining.
# 5.3391 s (44%) simulated in 3m 0s, estimated 3m 45s remaining.
# 7.1212 s (59%) simulated in 4m 0s, estimated 2m 44s remaining.
# 8.822 s (73%) simulated in 5m 0s, estimated 1m 48s remaining.
# 10.6323 s (88%) simulated in 6m 0s, estimated 46s remaining.
# 12. s (100%) simulated in 6m 48s
# 120000
# 120000
# EE 0.02751353679815828
# E_input_E 0.7608566671712317
# IE 1.080347001899642
# global excitatory rate: <neurons_E_rate.G: array([47.07656071])>
# run  41  of  60  completed
# Starting simulation at t=0.492 ks for a duration of 12. s
# 1.8854 s (15%) simulated in 1m 0s, estimated 5m 22s remaining.
# 3.6206 s (30%) simulated in 2m 0s, estimated 4m 38s remaining.
# 5.4402 s (45%) simulated in 3m 0s, estimated 3m 37s remaining.
# 7.2515 s (60%) simulated in 4m 0s, estimated 2m 37s remaining.
# 8.9759 s (74%) simulated in 5m 0s, estimated 1m 41s remaining.
# 10.7971 s (89%) simulated in 6m 0s, estimated 40s remaining.
# 12. s (100%) simulated in 6m 42s
# 120000
# 120000
# EE 0.027374773833511584
# E_input_E 0.7571144447466965
# IE 1.094343983756625
# global excitatory rate: <neurons_E_rate.G: array([47.45750106])>
# run  42  of  60  completed
# Starting simulation at t=0.504 ks for a duration of 12. s
# 1.8414 s (15%) simulated in 1m 0s, estimated 5m 31s remaining.
# 3.5804 s (29%) simulated in 2m 0s, estimated 4m 42s remaining.
# 5.3848 s (44%) simulated in 3m 0s, estimated 3m 41s remaining.
# 7.1617 s (59%) simulated in 4m 0s, estimated 2m 42s remaining.
# 8.8915 s (74%) simulated in 5m 0s, estimated 1m 45s remaining.
# 10.7072 s (89%) simulated in 6m 0s, estimated 43s remaining.
# 12. s (100%) simulated in 6m 46s
# 120000
# 120000
# EE 0.02729440097595419
# E_input_E 0.7534838943423589
# IE 1.1075622035415744
# global excitatory rate: <neurons_E_rate.G: array([47.73199289])>
# run  43  of  60  completed
# Starting simulation at t=0.516 ks for a duration of 12. s
# 1.9511 s (16%) simulated in 1m 0s, estimated 5m 9s remaining.
# 3.6751 s (30%) simulated in 2m 0s, estimated 4m 32s remaining.
# 5.4689 s (45%) simulated in 3m 0s, estimated 3m 35s remaining.
# 7.3502 s (61%) simulated in 4m 0s, estimated 2m 32s remaining.
# 9.0544 s (75%) simulated in 5m 0s, estimated 1m 38s remaining.
# 11.0469 s (92%) simulated in 6m 0s, estimated 31s remaining.
# 12. s (100%) simulated in 6m 32s
# 120000
# 120000
# EE 0.027668238059564684
# E_input_E 0.749199827354212
# IE 1.145247737300347
# global excitatory rate: <neurons_E_rate.G: array([41.90966791])>
# run  44  of  60  completed
# Starting simulation at t=0.528 ks for a duration of 12. s
# 1.9486 s (16%) simulated in 1m 0s, estimated 5m 10s remaining.
# 3.7101 s (30%) simulated in 2m 0s, estimated 4m 28s remaining.
# 5.5467 s (46%) simulated in 3m 0s, estimated 3m 29s remaining.
# 7.4584 s (62%) simulated in 4m 0s, estimated 2m 26s remaining.
# 9.281 s (77%) simulated in 5m 0s, estimated 1m 28s remaining.
# 11.1185 s (92%) simulated in 6m 0s, estimated 29s remaining.
# 12. s (100%) simulated in 6m 29s
# 120000
# 120000
# EE 0.027414064434767776
# E_input_E 0.7446752484894805
# IE 1.1858198770071058
# global excitatory rate: <neurons_E_rate.G: array([42.66369788])>
# run  45  of  60  completed
# Starting simulation at t=0.54 ks for a duration of 12. s
# 1.908 s (15%) simulated in 1m 0s, estimated 5m 17s remaining.
# 3.7082 s (30%) simulated in 2m 0s, estimated 4m 28s remaining.
# 5.5751 s (46%) simulated in 3m 0s, estimated 3m 27s remaining.
# 7.517 s (62%) simulated in 4m 0s, estimated 2m 23s remaining.
# 9.364 s (78%) simulated in 5m 0s, estimated 1m 24s remaining.
# 11.2754 s (93%) simulated in 6m 0s, estimated 23s remaining.
# 12. s (100%) simulated in 6m 24s
# 120000
# 120000
# EE 0.027467338832891673
# E_input_E 0.7402619323540955
# IE 1.2283473298029064
# global excitatory rate: <neurons_E_rate.G: array([41.71823217])>
# run  46  of  60  completed
# Starting simulation at t=0.552 ks for a duration of 12. s
# 1.9247 s (16%) simulated in 1m 0s, estimated 5m 14s remaining.
# 3.7483 s (31%) simulated in 2m 0s, estimated 4m 24s remaining.
# 5.5789 s (46%) simulated in 3m 0s, estimated 3m 27s remaining.
# 7.4644 s (62%) simulated in 4m 0s, estimated 2m 26s remaining.
# 9.2248 s (76%) simulated in 5m 0s, estimated 1m 30s remaining.
# 11.1679 s (93%) simulated in 6m 0s, estimated 27s remaining.
# 12. s (100%) simulated in 6m 27s
# 120000
# 120000
# EE 0.02663192464505507
# E_input_E 0.7361043254915459
# IE 1.2683011070349386
# global excitatory rate: <neurons_E_rate.G: array([42.83441099])>
# run  47  of  60  completed
# Starting simulation at t=0.564 ks for a duration of 12. s
# 1.91 s (15%) simulated in 1m 0s, estimated 5m 17s remaining.
# 3.6953 s (30%) simulated in 2m 0s, estimated 4m 30s remaining.
# 5.5152 s (45%) simulated in 3m 0s, estimated 3m 32s remaining.
# 7.3934 s (61%) simulated in 4m 0s, estimated 2m 30s remaining.
# 9.2481 s (77%) simulated in 5m 0s, estimated 1m 29s remaining.
# 11.1676 s (93%) simulated in 6m 0s, estimated 27s remaining.
# 12. s (100%) simulated in 6m 28s
# 120000
# 120000
# EE 0.027650819593508128
# E_input_E 0.7320381526926082
# IE 1.3071422744222942
# global excitatory rate: <neurons_E_rate.G: array([43.4899245])>
# run  48  of  60  completed
# Starting simulation at t=0.576 ks for a duration of 12. s
# 1.9644 s (16%) simulated in 1m 0s, estimated 5m 7s remaining.
# 3.7448 s (31%) simulated in 2m 0s, estimated 4m 25s remaining.
# 5.5473 s (46%) simulated in 3m 0s, estimated 3m 29s remaining.
# 7.4047 s (61%) simulated in 4m 0s, estimated 2m 29s remaining.
# 9.2201 s (76%) simulated in 5m 0s, estimated 1m 30s remaining.
# 11.1346 s (92%) simulated in 6m 0s, estimated 28s remaining.
# 12. s (100%) simulated in 6m 29s
# 120000
# 120000
# EE 0.02660714334113549
# E_input_E 0.7283141720532338
# IE 1.3467895149011881
# global excitatory rate: <neurons_E_rate.G: array([42.41767814])>
# run  49  of  60  completed
# Starting simulation at t=0.588 ks for a duration of 12. s
# 1.9691 s (16%) simulated in 1m 0s, estimated 5m 6s remaining.
# 3.8021 s (31%) simulated in 2m 0s, estimated 4m 19s remaining.
# 5.6225 s (46%) simulated in 3m 0s, estimated 3m 24s remaining.
# 7.5301 s (62%) simulated in 4m 0s, estimated 2m 22s remaining.
# 9.3282 s (77%) simulated in 5m 0s, estimated 1m 26s remaining.
# 11.2877 s (94%) simulated in 6m 0s, estimated 23s remaining.
# 12. s (100%) simulated in 6m 25s
# 120000
# 120000
# EE 0.02731244016212855
# E_input_E 0.7262224313867768
# IE 1.3846847057614478
# global excitatory rate: <neurons_E_rate.G: array([44.88527715])>
# run  50  of  60  completed
# Starting simulation at t=0.6 ks for a duration of 12. s
# 1.9572 s (16%) simulated in 1m 0s, estimated 5m 8s remaining.
# 3.7995 s (31%) simulated in 2m 0s, estimated 4m 19s remaining.
# 5.6866 s (47%) simulated in 3m 0s, estimated 3m 20s remaining.
# 7.5818 s (63%) simulated in 4m 0s, estimated 2m 20s remaining.
# 9.3774 s (78%) simulated in 5m 0s, estimated 1m 24s remaining.
# 11.2864 s (94%) simulated in 6m 0s, estimated 23s remaining.
# 12. s (100%) simulated in 6m 23s
# 120000
# 120000
# EE 0.026967404165066246
# E_input_E 0.7278045817326158
# IE 1.4230115578308005
# global excitatory rate: <neurons_E_rate.G: array([43.21824725])>
# run  51  of  60  completed
# Starting simulation at t=0.612 ks for a duration of 12. s
# 1.9387 s (16%) simulated in 1m 0s, estimated 5m 11s remaining.
# 3.7625 s (31%) simulated in 2m 0s, estimated 4m 23s remaining.
# 5.6131 s (46%) simulated in 3m 0s, estimated 3m 25s remaining.
# 7.4553 s (62%) simulated in 4m 0s, estimated 2m 26s remaining.
# 9.2322 s (76%) simulated in 5m 0s, estimated 1m 30s remaining.
# 11.0966 s (92%) simulated in 6m 0s, estimated 29s remaining.
# 12. s (100%) simulated in 6m 31s
# 120000
# 120000
# EE 0.028610694791447126
# E_input_E 0.7314433786772447
# IE 1.4627695040285273
# global excitatory rate: <neurons_E_rate.G: array([43.49353987])>
# run  52  of  60  completed
# Starting simulation at t=0.624 ks for a duration of 12. s
# 1.9008 s (15%) simulated in 1m 0s, estimated 5m 19s remaining.
# 3.6823 s (30%) simulated in 2m 0s, estimated 4m 31s remaining.
# 5.5397 s (46%) simulated in 3m 0s, estimated 3m 30s remaining.
# 7.4383 s (61%) simulated in 4m 0s, estimated 2m 27s remaining.
# 9.2037 s (76%) simulated in 5m 0s, estimated 1m 31s remaining.
# 11.0646 s (92%) simulated in 6m 0s, estimated 30s remaining.
# 12. s (100%) simulated in 6m 32s
# 120000
# 120000
# EE 0.02929698878356857
# E_input_E 0.7308566628815166
# IE 1.5029169045073072
# global excitatory rate: <neurons_E_rate.G: array([44.22737186])>
# run  53  of  60  completed
# Starting simulation at t=0.636 ks for a duration of 12. s
# 1.877 s (15%) simulated in 1m 0s, estimated 5m 24s remaining.
# 3.6297 s (30%) simulated in 2m 0s, estimated 4m 37s remaining.
# 5.4506 s (45%) simulated in 3m 0s, estimated 3m 36s remaining.
# 7.333 s (61%) simulated in 4m 0s, estimated 2m 33s remaining.
# 9.1257 s (76%) simulated in 5m 0s, estimated 1m 35s remaining.
# 11.0458 s (92%) simulated in 6m 0s, estimated 31s remaining.
# 12. s (100%) simulated in 6m 32s
# 120000
# 120000
# EE 0.028865214653805742
# E_input_E 0.7302926042877677
# IE 1.5449118197233265
# global excitatory rate: <neurons_E_rate.G: array([44.20966412])>
# run  54  of  60  completed
# Starting simulation at t=0.648 ks for a duration of 12. s
# 1.8911 s (15%) simulated in 1m 0s, estimated 5m 21s remaining.
# 3.6416 s (30%) simulated in 2m 0s, estimated 4m 35s remaining.
# 5.4725 s (45%) simulated in 3m 0s, estimated 3m 35s remaining.
# 7.3007 s (60%) simulated in 4m 0s, estimated 2m 34s remaining.
# 9.0432 s (75%) simulated in 5m 0s, estimated 1m 38s remaining.
# 10.955 s (91%) simulated in 6m 0s, estimated 34s remaining.
# 12. s (100%) simulated in 6m 35s
# 120000
# 120000
# EE 0.0290531533023195
# E_input_E 0.7310345819689315
# IE 1.585026459739517
# global excitatory rate: <neurons_E_rate.G: array([45.26468896])>
# run  55  of  60  completed
# Starting simulation at t=0.66 ks for a duration of 12. s
# 1.8668 s (15%) simulated in 1m 0s, estimated 5m 26s remaining.
# 3.6242 s (30%) simulated in 2m 0s, estimated 4m 37s remaining.
# 5.4426 s (45%) simulated in 3m 0s, estimated 3m 37s remaining.
# 7.2573 s (60%) simulated in 4m 0s, estimated 2m 37s remaining.
# 9.0423 s (75%) simulated in 5m 0s, estimated 1m 38s remaining.
# 10.9219 s (91%) simulated in 6m 0s, estimated 36s remaining.
# 12. s (100%) simulated in 6m 37s
# 120000
# 120000
# EE 0.029988562926557
# E_input_E 0.7286355185108557
# IE 1.6253826521903498
# global excitatory rate: <neurons_E_rate.G: array([44.91850459])>
# run  56  of  60  completed
# Starting simulation at t=0.672 ks for a duration of 12. s
# 1.9076 s (15%) simulated in 1m 0s, estimated 5m 17s remaining.
# 3.722 s (31%) simulated in 2m 0s, estimated 4m 27s remaining.
# 5.5392 s (46%) simulated in 3m 0s, estimated 3m 30s remaining.
# 7.3955 s (61%) simulated in 4m 0s, estimated 2m 29s remaining.
# 9.1521 s (76%) simulated in 5m 0s, estimated 1m 33s remaining.
# 11.2149 s (93%) simulated in 6m 0s, estimated 25s remaining.
# 12. s (100%) simulated in 6m 25s
# 120000
# 120000
# EE 0.031226058201031654
# E_input_E 0.7253800415464698
# IE 1.6668096339476135
# global excitatory rate: <neurons_E_rate.G: array([45.67304204])>
# run  57  of  60  completed
# Starting simulation at t=0.684 ks for a duration of 12. s
# 2.0335 s (16%) simulated in 1m 0s, estimated 4m 54s remaining.
# 3.8873 s (32%) simulated in 2m 0s, estimated 4m 10s remaining.
# 5.7616 s (48%) simulated in 3m 0s, estimated 3m 15s remaining.
# 7.772 s (64%) simulated in 4m 0s, estimated 2m 11s remaining.
# 9.6546 s (80%) simulated in 5m 0s, estimated 1m 13s remaining.
# 11.6172 s (96%) simulated in 6m 0s, estimated 12s remaining.
# 12. s (100%) simulated in 6m 12s
# 120000
# 120000
# EE 0.031911334267049875
# E_input_E 0.721452431853678
# IE 1.7077553635364928
# global excitatory rate: <neurons_E_rate.G: array([44.66481031])>
# run  58  of  60  completed
# Starting simulation at t=0.696 ks for a duration of 12. s
# 2.1212 s (17%) simulated in 1m 0s, estimated 4m 39s remaining.
# 4.1561 s (34%) simulated in 2m 0s, estimated 3m 46s remaining.
# 6.1353 s (51%) simulated in 3m 0s, estimated 2m 52s remaining.
# 8.2036 s (68%) simulated in 4m 0s, estimated 1m 51s remaining.
# 10.1387 s (84%) simulated in 5m 0s, estimated 55s remaining.
# 12. s (100%) simulated in 5m 58s
# 120000
# 120000
# EE 0.033302817989199054
# E_input_E 0.7176657430041555
# IE 1.7466711540068731
# global excitatory rate: <neurons_E_rate.G: array([45.25094342])>
# run  59  of  60  completed
# Starting simulation at t=0.708 ks for a duration of 12. s
# 2.0257 s (16%) simulated in 1m 0s, estimated 4m 55s remaining.
# 3.9652 s (33%) simulated in 2m 0s, estimated 4m 3s remaining.
# 5.8265 s (48%) simulated in 3m 0s, estimated 3m 11s remaining.
# 7.8091 s (65%) simulated in 4m 0s, estimated 2m 9s remaining.
# 9.7086 s (80%) simulated in 5m 0s, estimated 1m 11s remaining.
# 11.6736 s (97%) simulated in 6m 0s, estimated 10s remaining.
# 12. s (100%) simulated in 6m 10s
# 120000
# 120000
# EE 0.035206427504922325
# E_input_E 0.713945950013965
# IE 1.7854400911914783
# global excitatory rate: <neurons_E_rate.G: array([46.81553476])>
# run  60  of  60  completed
# saving data
# saving data
