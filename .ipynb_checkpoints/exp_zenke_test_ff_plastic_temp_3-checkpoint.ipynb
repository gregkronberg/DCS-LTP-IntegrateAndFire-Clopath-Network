# %%
import networks_3
import equations
import matplotlib.pyplot as plt
from brian2 import *
import imp
reload(equations)
reload(networks_3)
# Out:
# <module 'networks_3' from 'networks_3.pyc'>

# %%
neurons={'E_rate':{'t_H':1000*ms,'gamma':10.}}
trial_id = '2020-06-21-18-52-18-420000-87091_t_H_1_gamma_10_IE_02_FE_04'
w_IE_init=0.2
w_FE_init=.4
reinit_W=True

# %%
exp = networks_3.exp_zenke_test_ff_plastic()

# %%
exp.run(neurons=neurons, trial_id=trial_id, w_IE_init=w_IE_init, w_FE_init=w_FE_init, reinit_W=reinit_W)
# Out:
# {'rec_variables': [], 't_H': 1. * second, 'gamma': 10.0, 'N': 1}
# W_2020-06-21-18-52-18-420000-87091_t_H_1_gamma_10_IE_02_FE_04.pkl
# Starting simulation at t=0. s for a duration of 12. s
# 1.3435 s (11%) simulated in 1m 0s, estimated 7m 56s remaining.
# 2.525 s (21%) simulated in 2m 0s, estimated 7m 30s remaining.
# 3.6803 s (30%) simulated in 3m 0s, estimated 6m 47s remaining.
# 4.8512 s (40%) simulated in 4m 0s, estimated 5m 54s remaining.
# 5.9518 s (49%) simulated in 5m 0s, estimated 5m 5s remaining.
# 7.0281 s (58%) simulated in 6m 0s, estimated 4m 15s remaining.
# 8.078 s (67%) simulated in 7m 0s, estimated 3m 24s remaining.
# 9.0749 s (75%) simulated in 8m 0s, estimated 2m 35s remaining.
# 10.0766 s (83%) simulated in 9m 0s, estimated 1m 43s remaining.
# 11.094 s (92%) simulated in 10m 0s, estimated 49s remaining.
# 12. s (100%) simulated in 10m 53s
# 120000
# 120000
# EE 0.13911925337449532
# E_input_E 2.1151390776758405
# IE 3.186207394670642
# global excitatory rate: <neurons_E_rate.G: array([60.66337068])>
# run  1  of  60  completed
# Starting simulation at t=12. s for a duration of 12. s
# 0.9893 s (8%) simulated in 1m 0s, estimated 11m 8s remaining.
# 1.982 s (16%) simulated in 2m 0s, estimated 10m 7s remaining.
# 2.9789 s (24%) simulated in 3m 0s, estimated 9m 5s remaining.
# 3.981 s (33%) simulated in 4m 0s, estimated 8m 3s remaining.
# 4.9664 s (41%) simulated in 5m 0s, estimated 7m 5s remaining.
# 5.9504 s (49%) simulated in 6m 0s, estimated 6m 6s remaining.
# 6.9516 s (57%) simulated in 7m 0s, estimated 5m 5s remaining.
# 7.9564 s (66%) simulated in 8m 0s, estimated 4m 4s remaining.
# 8.956 s (74%) simulated in 9m 0s, estimated 3m 4s remaining.
# 9.9485 s (82%) simulated in 10m 0s, estimated 2m 4s remaining.
# 10.9427 s (91%) simulated in 11m 0s, estimated 1m 4s remaining.
# 11.9568 s (99%) simulated in 12m 0s, estimated 3s remaining.
# 12. s (100%) simulated in 12m 2s
# 120000
# 120000
# EE 0.13911925337449532
# E_input_E 2.1151390776758405
# IE 3.186207394670642
# global excitatory rate: <neurons_E_rate.G: array([61.07451451])>
# run  2  of  60  completed
# Starting simulation at t=24. s for a duration of 12. s
# 0.9844 s (8%) simulated in 1m 0s, estimated 11m 12s remaining.
# 1.9671 s (16%) simulated in 2m 0s, estimated 10m 12s remaining.
# 2.9356 s (24%) simulated in 3m 0s, estimated 9m 16s remaining.
# 3.9036 s (32%) simulated in 4m 0s, estimated 8m 18s remaining.
# 4.8784 s (40%) simulated in 5m 0s, estimated 7m 18s remaining.
# 5.8578 s (48%) simulated in 6m 0s, estimated 6m 18s remaining.
# 6.8518 s (57%) simulated in 7m 0s, estimated 5m 16s remaining.
# 7.8428 s (65%) simulated in 8m 0s, estimated 4m 14s remaining.
# 8.8284 s (73%) simulated in 9m 0s, estimated 3m 14s remaining.
# 9.7978 s (81%) simulated in 10m 0s, estimated 2m 15s remaining.
# 10.7737 s (89%) simulated in 11m 0s, estimated 1m 15s remaining.
# 11.7574 s (97%) simulated in 12m 0s, estimated 15s remaining.
# 12. s (100%) simulated in 12m 15s
# 120000
# 120000
# EE 0.1398819459077656
# E_input_E 2.114430196168854
# IE 3.194808460537832
# global excitatory rate: <neurons_E_rate.G: array([60.84611939])>
# run  3  of  60  completed
# Starting simulation at t=36. s for a duration of 12. s
# 1.0008 s (8%) simulated in 1m 0s, estimated 10m 59s remaining.
# 1.9982 s (16%) simulated in 2m 0s, estimated 10m 1s remaining.
# 2.988 s (24%) simulated in 3m 0s, estimated 9m 3s remaining.
# 3.9856 s (33%) simulated in 4m 0s, estimated 8m 3s remaining.
# 4.9602 s (41%) simulated in 5m 0s, estimated 7m 6s remaining.
# 5.938 s (49%) simulated in 6m 0s, estimated 6m 8s remaining.
# 6.919 s (57%) simulated in 7m 0s, estimated 5m 8s remaining.
# 7.9095 s (65%) simulated in 8m 0s, estimated 4m 8s remaining.
# 8.8958 s (74%) simulated in 9m 0s, estimated 3m 8s remaining.
# 9.8815 s (82%) simulated in 10m 0s, estimated 2m 9s remaining.
# 10.8505 s (90%) simulated in 11m 0s, estimated 1m 10s remaining.
# 11.8193 s (98%) simulated in 12m 0s, estimated 11s remaining.
# 12. s (100%) simulated in 12m 11s
# 120000
# 120000
# EE 0.1411738274049688
# E_input_E 2.1136223245742554
# IE 3.2034248218722365
# global excitatory rate: <neurons_E_rate.G: array([60.60661255])>
# run  4  of  60  completed
# Starting simulation at t=48. s for a duration of 12. s
# 0.9631 s (8%) simulated in 1m 0s, estimated 11m 28s remaining.
# 1.9309 s (16%) simulated in 2m 0s, estimated 10m 26s remaining.
# 2.9009 s (24%) simulated in 3m 0s, estimated 9m 25s remaining.
# 3.8826 s (32%) simulated in 4m 0s, estimated 8m 22s remaining.
# 4.8744 s (40%) simulated in 5m 0s, estimated 7m 19s remaining.
# 5.8323 s (48%) simulated in 6m 0s, estimated 6m 21s remaining.
# 6.8057 s (56%) simulated in 7m 0s, estimated 5m 21s remaining.
# 7.7808 s (64%) simulated in 8m 0s, estimated 4m 20s remaining.
# 8.751 s (72%) simulated in 9m 0s, estimated 3m 20s remaining.
# 9.7274 s (81%) simulated in 10m 0s, estimated 2m 20s remaining.
# 10.7246 s (89%) simulated in 11m 0s, estimated 1m 18s remaining.
# 11.7024 s (97%) simulated in 12m 0s, estimated 18s remaining.
# 12. s (100%) simulated in 12m 18s
# 120000
# 120000
# EE 0.14169324416862825
# E_input_E 2.112806826299125
# IE 3.211894408131511
# global excitatory rate: <neurons_E_rate.G: array([60.77542162])>
# run  5  of  60  completed
# Starting simulation at t=60. s for a duration of 12. s
# 0.9716 s (8%) simulated in 1m 0s, estimated 11m 21s remaining.
# 1.9384 s (16%) simulated in 2m 0s, estimated 10m 23s remaining.
# 2.9122 s (24%) simulated in 3m 0s, estimated 9m 22s remaining.
# 3.8815 s (32%) simulated in 4m 0s, estimated 8m 22s remaining.
# 4.8725 s (40%) simulated in 5m 0s, estimated 7m 19s remaining.
# 5.8555 s (48%) simulated in 6m 0s, estimated 6m 18s remaining.
# 6.8365 s (56%) simulated in 7m 0s, estimated 5m 17s remaining.
# 7.8088 s (65%) simulated in 8m 0s, estimated 4m 18s remaining.
# 8.7833 s (73%) simulated in 9m 0s, estimated 3m 18s remaining.
# 9.7569 s (81%) simulated in 10m 0s, estimated 2m 18s remaining.
# 10.7377 s (89%) simulated in 11m 0s, estimated 1m 18s remaining.
# 11.7168 s (97%) simulated in 12m 0s, estimated 17s remaining.
# 12. s (100%) simulated in 12m 17s
# 120000
# 120000
# EE 0.14252369339482324
# E_input_E 2.1120014398150193
# IE 3.2202569153407525
# global excitatory rate: <neurons_E_rate.G: array([60.06406005])>
# run  6  of  60  completed
# Starting simulation at t=72. s for a duration of 12. s
# 0.9859 s (8%) simulated in 1m 0s, estimated 11m 10s remaining.
# 1.9712 s (16%) simulated in 2m 0s, estimated 10m 11s remaining.
# 2.936 s (24%) simulated in 3m 0s, estimated 9m 16s remaining.
# 3.9037 s (32%) simulated in 4m 0s, estimated 8m 18s remaining.
# 4.8728 s (40%) simulated in 5m 0s, estimated 7m 19s remaining.
# 5.862 s (48%) simulated in 6m 0s, estimated 6m 17s remaining.
# 6.8386 s (56%) simulated in 7m 0s, estimated 5m 17s remaining.
# 7.8135 s (65%) simulated in 8m 0s, estimated 4m 17s remaining.
# 8.784 s (73%) simulated in 9m 0s, estimated 3m 18s remaining.
# 9.7837 s (81%) simulated in 10m 0s, estimated 2m 16s remaining.
# 10.7729 s (89%) simulated in 11m 0s, estimated 1m 15s remaining.
# 11.7751 s (98%) simulated in 12m 0s, estimated 14s remaining.
# 12. s (100%) simulated in 12m 13s
# 120000
# 120000
# EE 0.1432656366314508
# E_input_E 2.111210560905969
# IE 3.2286263685172947
# global excitatory rate: <neurons_E_rate.G: array([60.78870242])>
# run  7  of  60  completed
# Starting simulation at t=84. s for a duration of 12. s
# 0.9721 s (8%) simulated in 1m 0s, estimated 11m 21s remaining.
# 1.9414 s (16%) simulated in 2m 0s, estimated 10m 22s remaining.
# 2.9438 s (24%) simulated in 3m 0s, estimated 9m 14s remaining.
# 3.9719 s (33%) simulated in 4m 0s, estimated 8m 5s remaining.
# 4.9611 s (41%) simulated in 5m 0s, estimated 7m 6s remaining.
# 5.975 s (49%) simulated in 6m 0s, estimated 6m 3s remaining.
# 7.0188 s (58%) simulated in 7m 0s, estimated 4m 58s remaining.
# 8.0308 s (66%) simulated in 8m 0s, estimated 3m 57s remaining.
# 9.0565 s (75%) simulated in 9m 0s, estimated 2m 56s remaining.
# 10.071 s (83%) simulated in 10m 0s, estimated 1m 55s remaining.
# 11.0546 s (92%) simulated in 11m 0s, estimated 56s remaining.
# 12. s (100%) simulated in 11m 56s
# 120000
# 120000
# EE 0.14441273905826202
# E_input_E 2.1099488588618818
# IE 3.2366213461088367
# global excitatory rate: <neurons_E_rate.G: array([58.16398874])>
# run  8  of  60  completed
# Starting simulation at t=96. s for a duration of 12. s
# 1.0213 s (8%) simulated in 1m 0s, estimated 10m 45s remaining.
# 1.9985 s (16%) simulated in 2m 0s, estimated 10m 1s remaining.
# 2.9889 s (24%) simulated in 3m 0s, estimated 9m 3s remaining.
# 4.0081 s (33%) simulated in 4m 0s, estimated 7m 59s remaining.
# 4.9855 s (41%) simulated in 5m 0s, estimated 7m 2s remaining.
# 5.9596 s (49%) simulated in 6m 0s, estimated 6m 5s remaining.
# 6.9595 s (57%) simulated in 7m 0s, estimated 5m 4s remaining.
# 7.9314 s (66%) simulated in 8m 0s, estimated 4m 6s remaining.
# 8.916 s (74%) simulated in 9m 0s, estimated 3m 7s remaining.
# 9.9247 s (82%) simulated in 10m 0s, estimated 2m 5s remaining.
# 10.8982 s (90%) simulated in 11m 0s, estimated 1m 7s remaining.
# 11.8897 s (99%) simulated in 12m 0s, estimated 7s remaining.
# 12. s (100%) simulated in 12m 6s
# 120000
# 120000
# EE 0.145201290582405
# E_input_E 2.1087834990521652
# IE 3.244327830280509
# global excitatory rate: <neurons_E_rate.G: array([58.07014627])>
# run  9  of  60  completed
# Starting simulation at t=108. s for a duration of 12. s
# 0.9887 s (8%) simulated in 1m 0s, estimated 11m 8s remaining.
# 1.9522 s (16%) simulated in 2m 0s, estimated 10m 18s remaining.
# 2.9306 s (24%) simulated in 3m 0s, estimated 9m 17s remaining.
# 3.9413 s (32%) simulated in 4m 0s, estimated 8m 11s remaining.
# 4.9116 s (40%) simulated in 5m 0s, estimated 7m 13s remaining.
# 5.9105 s (49%) simulated in 6m 0s, estimated 6m 11s remaining.
# 6.9388 s (57%) simulated in 7m 0s, estimated 5m 6s remaining.
# 7.9162 s (65%) simulated in 8m 0s, estimated 4m 8s remaining.
# 8.9171 s (74%) simulated in 9m 0s, estimated 3m 7s remaining.
# 9.9228 s (82%) simulated in 10m 0s, estimated 2m 6s remaining.
# 10.9013 s (90%) simulated in 11m 0s, estimated 1m 7s remaining.
# 11.8831 s (99%) simulated in 12m 0s, estimated 7s remaining.
# 12. s (100%) simulated in 12m 6s
# 120000
# 120000
# EE 0.14588674532067505
# E_input_E 2.107605110933575
# IE 3.2521112094003337
# global excitatory rate: <neurons_E_rate.G: array([58.39447789])>
# run  10  of  60  completed
# Starting simulation at t=120. s for a duration of 12. s
# 1. s (8%) simulated in 1m 0s, estimated 11m 0s remaining.
# 1.9887 s (16%) simulated in 2m 0s, estimated 10m 4s remaining.
# 2.9778 s (24%) simulated in 3m 0s, estimated 9m 5s remaining.
# 3.9908 s (33%) simulated in 4m 0s, estimated 8m 2s remaining.
# 4.9686 s (41%) simulated in 5m 0s, estimated 7m 5s remaining.
# 5.9564 s (49%) simulated in 6m 0s, estimated 6m 5s remaining.
# 6.9842 s (58%) simulated in 7m 0s, estimated 5m 2s remaining.
# 7.9527 s (66%) simulated in 8m 0s, estimated 4m 4s remaining.
# 8.9382 s (74%) simulated in 9m 0s, estimated 3m 5s remaining.
# 9.9487 s (82%) simulated in 10m 0s, estimated 2m 4s remaining.
# 10.9304 s (91%) simulated in 11m 0s, estimated 1m 5s remaining.
# 11.9169 s (99%) simulated in 12m 0s, estimated 5s remaining.
# 12. s (100%) simulated in 12m 4s
# 120000
# 120000
# EE 0.1467545790946595
# E_input_E 2.1064937831478328
# IE 3.259838592486867
# global excitatory rate: <neurons_E_rate.G: array([58.67881843])>
# run  11  of  60  completed
# Starting simulation at t=132. s for a duration of 12. s
# 1.0148 s (8%) simulated in 1m 0s, estimated 10m 50s remaining.
# 2.0001 s (16%) simulated in 2m 0s, estimated 10m 0s remaining.
# 3.0007 s (25%) simulated in 3m 0s, estimated 9m 0s remaining.
# 4.0124 s (33%) simulated in 4m 0s, estimated 7m 58s remaining.
# 4.993 s (41%) simulated in 5m 0s, estimated 7m 1s remaining.
# 5.9756 s (49%) simulated in 6m 0s, estimated 6m 3s remaining.
# 6.9898 s (58%) simulated in 7m 0s, estimated 5m 1s remaining.
# 7.9733 s (66%) simulated in 8m 0s, estimated 4m 2s remaining.
# 8.9568 s (74%) simulated in 9m 0s, estimated 3m 4s remaining.
# 9.984 s (83%) simulated in 10m 0s, estimated 2m 1s remaining.
# 10.9588 s (91%) simulated in 11m 0s, estimated 1m 3s remaining.
# 11.9484 s (99%) simulated in 12m 0s, estimated 3s remaining.
# 12. s (100%) simulated in 12m 3s
# 120000
# 120000
# EE 0.14745868128135994
# E_input_E 2.1053607547350146
# IE 3.2671725266745204
# global excitatory rate: <neurons_E_rate.G: array([58.7724079])>
# run  12  of  60  completed
# Starting simulation at t=144. s for a duration of 12. s
# 1.0123 s (8%) simulated in 1m 0s, estimated 10m 51s remaining.
# 1.9976 s (16%) simulated in 2m 0s, estimated 10m 1s remaining.
# 3.0033 s (25%) simulated in 3m 0s, estimated 8m 59s remaining.
# 4.0381 s (33%) simulated in 4m 0s, estimated 7m 53s remaining.
# 5.0209 s (41%) simulated in 5m 0s, estimated 6m 57s remaining.
# 6.025 s (50%) simulated in 6m 0s, estimated 5m 57s remaining.
# 7.0405 s (58%) simulated in 7m 0s, estimated 4m 56s remaining.
# 8.0159 s (66%) simulated in 8m 0s, estimated 3m 59s remaining.
# 8.9978 s (74%) simulated in 9m 0s, estimated 3m 0s remaining.
# 10.0032 s (83%) simulated in 10m 0s, estimated 2m 0s remaining.
# 10.9865 s (91%) simulated in 11m 0s, estimated 1m 1s remaining.
# 11.9753 s (99%) simulated in 12m 0s, estimated 1s remaining.
# 12. s (100%) simulated in 12m 1s
# 120000
# 120000
# EE 0.14730792907095172
# E_input_E 2.104223511181651
# IE 3.2746906688115853
# global excitatory rate: <neurons_E_rate.G: array([57.87160326])>
# run  13  of  60  completed
# Starting simulation at t=156. s for a duration of 12. s
# 1.004 s (8%) simulated in 1m 0s, estimated 10m 57s remaining.
# 1.9714 s (16%) simulated in 2m 0s, estimated 10m 11s remaining.
# 2.952 s (24%) simulated in 3m 0s, estimated 9m 12s remaining.
# 3.9506 s (32%) simulated in 4m 0s, estimated 8m 9s remaining.
# 4.9073 s (40%) simulated in 5m 0s, estimated 7m 14s remaining.
# 5.9016 s (49%) simulated in 6m 0s, estimated 6m 12s remaining.
# 6.9229 s (57%) simulated in 7m 0s, estimated 5m 8s remaining.
# 7.8993 s (65%) simulated in 8m 0s, estimated 4m 9s remaining.
# 8.883 s (74%) simulated in 9m 0s, estimated 3m 10s remaining.
# 9.893 s (82%) simulated in 10m 0s, estimated 2m 8s remaining.
# 10.8733 s (90%) simulated in 11m 0s, estimated 1m 8s remaining.
# 11.8405 s (98%) simulated in 12m 0s, estimated 10s remaining.
# 12. s (100%) simulated in 12m 9s
# 120000
# 120000
# EE 0.1485348897391137
# E_input_E 2.1031346022346047
# IE 3.28209481876441
# global excitatory rate: <neurons_E_rate.G: array([58.65217192])>
# run  14  of  60  completed
# Starting simulation at t=168. s for a duration of 12. s
# 1.0053 s (8%) simulated in 1m 0s, estimated 10m 56s remaining.
# 1.9771 s (16%) simulated in 2m 0s, estimated 10m 8s remaining.
# 2.9854 s (24%) simulated in 3m 0s, estimated 9m 4s remaining.
# 3.995 s (33%) simulated in 4m 0s, estimated 8m 1s remaining.
# 4.9594 s (41%) simulated in 5m 0s, estimated 7m 6s remaining.
# 5.9534 s (49%) simulated in 6m 0s, estimated 6m 6s remaining.
# 6.9508 s (57%) simulated in 7m 0s, estimated 5m 5s remaining.
# 7.9323 s (66%) simulated in 8m 0s, estimated 4m 6s remaining.
# 8.9165 s (74%) simulated in 9m 0s, estimated 3m 7s remaining.
# 9.9511 s (82%) simulated in 10m 0s, estimated 2m 4s remaining.
# 10.9179 s (90%) simulated in 11m 0s, estimated 1m 5s remaining.
# 11.8927 s (99%) simulated in 12m 0s, estimated 6s remaining.
# 12. s (100%) simulated in 12m 6s
# 120000
# 120000
# EE 0.14948272707633203
# E_input_E 2.1020840948065986
# IE 3.289481956813955
# global excitatory rate: <neurons_E_rate.G: array([59.08459222])>
# run  15  of  60  completed
# Starting simulation at t=180. s for a duration of 12. s
# 1.0009 s (8%) simulated in 1m 0s, estimated 10m 59s remaining.
# 2.0216 s (16%) simulated in 2m 0s, estimated 9m 52s remaining.
# 3.0822 s (25%) simulated in 3m 0s, estimated 8m 41s remaining.
# 4.1506 s (34%) simulated in 4m 0s, estimated 7m 34s remaining.
# 5.1357 s (42%) simulated in 5m 0s, estimated 6m 41s remaining.
# 6.1387 s (51%) simulated in 6m 0s, estimated 5m 44s remaining.
# 7.1597 s (59%) simulated in 7m 0s, estimated 4m 44s remaining.
# 8.1126 s (67%) simulated in 8m 0s, estimated 3m 50s remaining.
# 9.1271 s (76%) simulated in 9m 0s, estimated 2m 50s remaining.
# 10.1132 s (84%) simulated in 10m 0s, estimated 1m 52s remaining.
# 11.0763 s (92%) simulated in 11m 0s, estimated 55s remaining.
# 12. s (100%) simulated in 11m 55s
# 120000
# 120000
# EE 0.14979657361260643
# E_input_E 2.1010220860922444
# IE 3.2969214003206333
# global excitatory rate: <neurons_E_rate.G: array([58.98973732])>
# run  16  of  60  completed
# Starting simulation at t=192. s for a duration of 12. s
# 1.0102 s (8%) simulated in 1m 0s, estimated 10m 53s remaining.
# 1.9807 s (16%) simulated in 2m 0s, estimated 10m 7s remaining.
# 3.0028 s (25%) simulated in 3m 0s, estimated 8m 59s remaining.
# 4.0185 s (33%) simulated in 4m 0s, estimated 7m 57s remaining.
# 4.9847 s (41%) simulated in 5m 0s, estimated 7m 2s remaining.
# 5.9639 s (49%) simulated in 6m 0s, estimated 6m 4s remaining.
# 6.9642 s (58%) simulated in 7m 0s, estimated 5m 4s remaining.
# 7.9442 s (66%) simulated in 8m 0s, estimated 4m 5s remaining.
# 8.9451 s (74%) simulated in 9m 0s, estimated 3m 4s remaining.
# 9.9473 s (82%) simulated in 10m 0s, estimated 2m 4s remaining.
# 10.9124 s (90%) simulated in 11m 0s, estimated 1m 6s remaining.
# 11.886 s (99%) simulated in 12m 0s, estimated 7s remaining.
# 12. s (100%) simulated in 12m 6s
# 120000
# 120000
# EE 0.15021439277441062
# E_input_E 2.0999708890324142
# IE 3.3045459269102255
# global excitatory rate: <neurons_E_rate.G: array([58.471131])>
# run  17  of  60  completed
# Starting simulation at t=204. s for a duration of 12. s
# 1.0003 s (8%) simulated in 1m 0s, estimated 11m 0s remaining.
# 1.9838 s (16%) simulated in 2m 0s, estimated 10m 6s remaining.
# 2.9936 s (24%) simulated in 3m 0s, estimated 9m 2s remaining.
# 4.0246 s (33%) simulated in 4m 0s, estimated 7m 56s remaining.
# 5.0053 s (41%) simulated in 5m 0s, estimated 6m 59s remaining.
# 6.0003 s (50%) simulated in 6m 0s, estimated 6m 0s remaining.
# 7.0142 s (58%) simulated in 7m 0s, estimated 4m 59s remaining.
# 7.9816 s (66%) simulated in 8m 0s, estimated 4m 2s remaining.
# 8.9715 s (74%) simulated in 9m 0s, estimated 3m 2s remaining.
# 10.003 s (83%) simulated in 10m 0s, estimated 2m 0s remaining.
# 10.9854 s (91%) simulated in 11m 0s, estimated 1m 1s remaining.
# 11.9891 s (99%) simulated in 12m 0s, estimated 1s remaining.
# 12. s (100%) simulated in 12m 0s
# 120000
# 120000
# EE 0.15125249079150202
# E_input_E 2.09896507068363
# IE 3.3117777556764465
# global excitatory rate: <neurons_E_rate.G: array([58.45822036])>
# run  18  of  60  completed
# Starting simulation at t=216. s for a duration of 12. s
# 1.0045 s (8%) simulated in 1m 0s, estimated 10m 57s remaining.
# 1.9884 s (16%) simulated in 2m 0s, estimated 10m 4s remaining.
# 2.994 s (24%) simulated in 3m 0s, estimated 9m 1s remaining.
# 4.0172 s (33%) simulated in 4m 0s, estimated 7m 57s remaining.
# 5.016 s (41%) simulated in 5m 0s, estimated 6m 58s remaining.
# 6.0324 s (50%) simulated in 6m 0s, estimated 5m 56s remaining.
# 7.0554 s (58%) simulated in 7m 0s, estimated 4m 54s remaining.
# 8.0396 s (66%) simulated in 8m 0s, estimated 3m 56s remaining.
# 9.0417 s (75%) simulated in 9m 0s, estimated 2m 57s remaining.
# 10.0454 s (83%) simulated in 10m 0s, estimated 1m 57s remaining.
# 10.997 s (91%) simulated in 11m 0s, estimated 1m 0s remaining.
# 12. s (100%) simulated in 11m 59s
# 120000
# 120000
# EE 0.15183906613593381
# E_input_E 2.0979711221000024
# IE 3.3190065164056244
# global excitatory rate: <neurons_E_rate.G: array([58.36411874])>
# run  19  of  60  completed
# Starting simulation at t=228. s for a duration of 12. s
# 1.02 s (8%) simulated in 1m 0s, estimated 10m 46s remaining.
# 2.0183 s (16%) simulated in 2m 0s, estimated 9m 54s remaining.
# 3.0246 s (25%) simulated in 3m 0s, estimated 8m 54s remaining.
# 4.0305 s (33%) simulated in 4m 0s, estimated 7m 55s remaining.
# 5.0074 s (41%) simulated in 5m 0s, estimated 6m 59s remaining.
# 6.001 s (50%) simulated in 6m 0s, estimated 6m 0s remaining.
# 6.9934 s (58%) simulated in 7m 0s, estimated 5m 1s remaining.
# 7.9607 s (66%) simulated in 8m 0s, estimated 4m 4s remaining.
# 8.955 s (74%) simulated in 9m 0s, estimated 3m 4s remaining.
# 9.9648 s (83%) simulated in 10m 0s, estimated 2m 3s remaining.
# 10.9258 s (91%) simulated in 11m 0s, estimated 1m 5s remaining.
# 11.9057 s (99%) simulated in 12m 0s, estimated 6s remaining.
# 12. s (100%) simulated in 12m 5s
# 120000
# 120000
# EE 0.1521658228287401
# E_input_E 2.096906388420646
# IE 3.326198983678798
# global excitatory rate: <neurons_E_rate.G: array([58.86991358])>
# run  20  of  60  completed
# Starting simulation at t=240. s for a duration of 12. s
# 1.0024 s (8%) simulated in 1m 0s, estimated 10m 58s remaining.
# 1.9645 s (16%) simulated in 2m 0s, estimated 10m 13s remaining.
# 2.9656 s (24%) simulated in 3m 0s, estimated 9m 8s remaining.
# 3.9784 s (33%) simulated in 4m 0s, estimated 8m 4s remaining.
# 4.9572 s (41%) simulated in 5m 0s, estimated 7m 6s remaining.
# 5.9333 s (49%) simulated in 6m 0s, estimated 6m 8s remaining.
# 6.9253 s (57%) simulated in 7m 0s, estimated 5m 8s remaining.
# 7.8843 s (65%) simulated in 8m 0s, estimated 4m 11s remaining.
# 8.8742 s (73%) simulated in 9m 0s, estimated 3m 10s remaining.
# 9.8905 s (82%) simulated in 10m 0s, estimated 2m 8s remaining.
# 10.8694 s (90%) simulated in 11m 0s, estimated 1m 9s remaining.
# 11.8619 s (98%) simulated in 12m 0s, estimated 8s remaining.
# 12. s (100%) simulated in 12m 8s
# 120000
# 120000
# EE 0.15282910984597795
# E_input_E 2.0959559108723154
# IE 3.3332959124528716
# global excitatory rate: <neurons_E_rate.G: array([58.52982499])>
# run  21  of  60  completed
# Starting simulation at t=252. s for a duration of 12. s
# 0.9962 s (8%) simulated in 1m 0s, estimated 11m 3s remaining.
# 1.9669 s (16%) simulated in 2m 0s, estimated 10m 12s remaining.
# 2.9452 s (24%) simulated in 3m 0s, estimated 9m 13s remaining.
# 3.9561 s (32%) simulated in 4m 0s, estimated 8m 8s remaining.
# 4.9258 s (41%) simulated in 5m 0s, estimated 7m 11s remaining.
# 5.9251 s (49%) simulated in 6m 0s, estimated 6m 9s remaining.
# 6.918 s (57%) simulated in 7m 0s, estimated 5m 9s remaining.
# 7.887 s (65%) simulated in 8m 0s, estimated 4m 10s remaining.
# 8.8604 s (73%) simulated in 9m 0s, estimated 3m 11s remaining.
# 9.8736 s (82%) simulated in 10m 0s, estimated 2m 9s remaining.
# 10.8605 s (90%) simulated in 11m 0s, estimated 1m 9s remaining.
# 11.8399 s (98%) simulated in 12m 0s, estimated 10s remaining.
# 12. s (100%) simulated in 12m 9s
# 120000
# 120000
# EE 0.15359903370780628
# E_input_E 2.094989835309447
# IE 3.340291604526092
# global excitatory rate: <neurons_E_rate.G: array([58.48578102])>
# run  22  of  60  completed
# Starting simulation at t=264. s for a duration of 12. s
# 1.0054 s (8%) simulated in 1m 0s, estimated 10m 56s remaining.
# 1.985 s (16%) simulated in 2m 0s, estimated 10m 6s remaining.
# 2.993 s (24%) simulated in 3m 0s, estimated 9m 2s remaining.
# 4.0282 s (33%) simulated in 4m 0s, estimated 7m 55s remaining.
# 5.0161 s (41%) simulated in 5m 0s, estimated 6m 58s remaining.
# 6.0055 s (50%) simulated in 6m 0s, estimated 5m 59s remaining.
# 7.0198 s (58%) simulated in 7m 0s, estimated 4m 58s remaining.
# 8.0058 s (66%) simulated in 8m 0s, estimated 4m 0s remaining.
# 9.0052 s (75%) simulated in 9m 0s, estimated 3m 0s remaining.
# 10.0081 s (83%) simulated in 10m 0s, estimated 1m 59s remaining.
# 10.9884 s (91%) simulated in 11m 0s, estimated 1m 1s remaining.
# 11.9876 s (99%) simulated in 12m 0s, estimated 1s remaining.
# 12. s (100%) simulated in 12m 0s
# 120000
# 120000
# EE 0.15409530267296803
# E_input_E 2.0940107490835094
# IE 3.3473515846630053
# global excitatory rate: <neurons_E_rate.G: array([58.34608296])>
# run  23  of  60  completed
# Starting simulation at t=276. s for a duration of 12. s
# 0.9958 s (8%) simulated in 1m 0s, estimated 11m 3s remaining.
# 1.9863 s (16%) simulated in 2m 0s, estimated 10m 5s remaining.
# 2.9846 s (24%) simulated in 3m 0s, estimated 9m 4s remaining.
# 3.9774 s (33%) simulated in 4m 0s, estimated 8m 4s remaining.
# 4.92 s (41%) simulated in 5m 0s, estimated 7m 12s remaining.
# 5.9113 s (49%) simulated in 6m 0s, estimated 6m 11s remaining.
# 6.902 s (57%) simulated in 7m 0s, estimated 5m 10s remaining.
# 7.8852 s (65%) simulated in 8m 0s, estimated 4m 11s remaining.
# 8.8984 s (74%) simulated in 9m 0s, estimated 3m 8s remaining.
# 9.8959 s (82%) simulated in 10m 0s, estimated 2m 8s remaining.
# 10.8627 s (90%) simulated in 11m 0s, estimated 1m 9s remaining.
# 11.8574 s (98%) simulated in 12m 0s, estimated 9s remaining.
# 12. s (100%) simulated in 12m 8s
# 120000
# 120000
# EE 0.15492587278455483
# E_input_E 2.0930930563618126
# IE 3.354494041446527
# global excitatory rate: <neurons_E_rate.G: array([57.85982873])>
# run  24  of  60  completed
# Starting simulation at t=288. s for a duration of 12. s
# 0.9923 s (8%) simulated in 1m 0s, estimated 11m 6s remaining.
# 1.9624 s (16%) simulated in 2m 0s, estimated 10m 14s remaining.
# 2.9529 s (24%) simulated in 3m 0s, estimated 9m 12s remaining.
# 3.9622 s (33%) simulated in 4m 0s, estimated 8m 7s remaining.
# 4.9387 s (41%) simulated in 5m 0s, estimated 7m 9s remaining.
# 5.9063 s (49%) simulated in 6m 0s, estimated 6m 11s remaining.
# 6.9398 s (57%) simulated in 7m 0s, estimated 5m 6s remaining.
# 7.915 s (65%) simulated in 8m 0s, estimated 4m 8s remaining.
# 8.9009 s (74%) simulated in 9m 0s, estimated 3m 8s remaining.
# 9.9236 s (82%) simulated in 10m 0s, estimated 2m 6s remaining.
# 10.8968 s (90%) simulated in 11m 0s, estimated 1m 7s remaining.
# 11.8752 s (98%) simulated in 12m 0s, estimated 8s remaining.
# 12. s (100%) simulated in 12m 7s
# 120000
# 120000
# EE 0.15516108631870487
# E_input_E 2.092163944222346
# IE 3.3614380165267894
# global excitatory rate: <neurons_E_rate.G: array([58.31583514])>
# run  25  of  60  completed
# Starting simulation at t=300. s for a duration of 12. s
# 1.0034 s (8%) simulated in 1m 0s, estimated 10m 58s remaining.
# 1.975 s (16%) simulated in 2m 0s, estimated 10m 9s remaining.
# 2.975 s (24%) simulated in 3m 0s, estimated 9m 6s remaining.
# 4.0058 s (33%) simulated in 4m 0s, estimated 7m 59s remaining.
# 4.9941 s (41%) simulated in 5m 0s, estimated 7m 1s remaining.
# 5.9938 s (49%) simulated in 6m 0s, estimated 6m 1s remaining.
# 6.9943 s (58%) simulated in 7m 0s, estimated 5m 1s remaining.
# 7.9721 s (66%) simulated in 8m 0s, estimated 4m 3s remaining.
# 8.9599 s (74%) simulated in 9m 0s, estimated 3m 3s remaining.
# 9.9712 s (83%) simulated in 10m 0s, estimated 2m 2s remaining.
# 10.9582 s (91%) simulated in 11m 0s, estimated 1m 3s remaining.
# 11.9519 s (99%) simulated in 12m 0s, estimated 3s remaining.
# 12. s (100%) simulated in 12m 2s
# 120000
# 120000
# EE 0.1562238796166155
# E_input_E 2.091257211030103
# IE 3.3682447252923096
# global excitatory rate: <neurons_E_rate.G: array([58.71376397])>
# run  26  of  60  completed
# Starting simulation at t=312. s for a duration of 12. s
# 1.0049 s (8%) simulated in 1m 0s, estimated 10m 57s remaining.
# 1.9818 s (16%) simulated in 2m 0s, estimated 10m 7s remaining.
# 2.9659 s (24%) simulated in 3m 0s, estimated 9m 8s remaining.
# 3.9751 s (33%) simulated in 4m 0s, estimated 8m 5s remaining.
# 4.9322 s (41%) simulated in 5m 0s, estimated 7m 10s remaining.
# 5.9114 s (49%) simulated in 6m 0s, estimated 6m 11s remaining.
# 6.9241 s (57%) simulated in 7m 0s, estimated 5m 8s remaining.
# 7.9177 s (65%) simulated in 8m 0s, estimated 4m 8s remaining.
# 8.9088 s (74%) simulated in 9m 0s, estimated 3m 7s remaining.
# 9.9134 s (82%) simulated in 10m 0s, estimated 2m 6s remaining.
# 10.891 s (90%) simulated in 11m 0s, estimated 1m 7s remaining.
# 11.8863 s (99%) simulated in 12m 0s, estimated 7s remaining.
# 12. s (100%) simulated in 12m 6s
# 120000
# 120000
# EE 0.15670339015656862
# E_input_E 2.0903803680971835
# IE 3.3749706545442226
# global excitatory rate: <neurons_E_rate.G: array([58.42848642])>
# run  27  of  60  completed
# Starting simulation at t=0.324 ks for a duration of 12. s
# 1.0192 s (8%) simulated in 1m 0s, estimated 10m 47s remaining.
# 2.0169 s (16%) simulated in 2m 0s, estimated 9m 54s remaining.
# 3.0566 s (25%) simulated in 3m 0s, estimated 8m 47s remaining.
# 4.0715 s (33%) simulated in 4m 0s, estimated 7m 47s remaining.
# 5.0483 s (42%) simulated in 5m 0s, estimated 6m 53s remaining.
# 6.0663 s (50%) simulated in 6m 0s, estimated 5m 52s remaining.
# 7.075 s (58%) simulated in 7m 0s, estimated 4m 52s remaining.
# 8.0409 s (67%) simulated in 8m 0s, estimated 3m 56s remaining.
# 9.0506 s (75%) simulated in 9m 0s, estimated 2m 56s remaining.
# 10.0709 s (83%) simulated in 10m 0s, estimated 1m 55s remaining.
# 11.0344 s (91%) simulated in 11m 0s, estimated 58s remaining.
# 12. s (100%) simulated in 11m 58s
# 120000
# 120000
# EE 0.15756732446932908
# E_input_E 2.0895608193845616
# IE 3.3817113410996353
# global excitatory rate: <neurons_E_rate.G: array([58.13770225])>
# run  28  of  60  completed
# Starting simulation at t=0.336 ks for a duration of 12. s
# 1.0001 s (8%) simulated in 1m 0s, estimated 11m 0s remaining.
# 1.9543 s (16%) simulated in 2m 0s, estimated 10m 17s remaining.
# 2.9404 s (24%) simulated in 3m 0s, estimated 9m 15s remaining.
# 3.9434 s (32%) simulated in 4m 0s, estimated 8m 10s remaining.
# 4.9207 s (41%) simulated in 5m 0s, estimated 7m 12s remaining.
# 5.9126 s (49%) simulated in 6m 0s, estimated 6m 11s remaining.
# 6.9172 s (57%) simulated in 7m 0s, estimated 5m 9s remaining.
# 7.8788 s (65%) simulated in 8m 0s, estimated 4m 11s remaining.
# 8.8559 s (73%) simulated in 9m 0s, estimated 3m 12s remaining.
# 9.8642 s (82%) simulated in 10m 0s, estimated 2m 10s remaining.
# 10.8433 s (90%) simulated in 11m 0s, estimated 1m 10s remaining.
# 11.8264 s (98%) simulated in 12m 0s, estimated 11s remaining.
# 12. s (100%) simulated in 12m 10s
# 120000
# 120000
# EE 0.15780787785206504
# E_input_E 2.0886694115368996
# IE 3.388497491142823
# global excitatory rate: <neurons_E_rate.G: array([58.52393689])>
# run  29  of  60  completed
# Starting simulation at t=0.348 ks for a duration of 12. s
# 1.0098 s (8%) simulated in 1m 0s, estimated 10m 53s remaining.
# 1.9941 s (16%) simulated in 2m 0s, estimated 10m 2s remaining.
# 2.9877 s (24%) simulated in 3m 0s, estimated 9m 3s remaining.
# 4.0001 s (33%) simulated in 4m 0s, estimated 8m 0s remaining.
# 4.9612 s (41%) simulated in 5m 0s, estimated 7m 6s remaining.
# 5.9652 s (49%) simulated in 6m 0s, estimated 6m 4s remaining.
# 6.9726 s (58%) simulated in 7m 0s, estimated 5m 3s remaining.
# 7.9577 s (66%) simulated in 8m 0s, estimated 4m 4s remaining.
# 8.9702 s (74%) simulated in 9m 0s, estimated 3m 2s remaining.
# 9.9915 s (83%) simulated in 10m 0s, estimated 2m 1s remaining.
# 10.9468 s (91%) simulated in 11m 0s, estimated 1m 4s remaining.
# 11.9163 s (99%) simulated in 12m 0s, estimated 5s remaining.
# 12. s (100%) simulated in 12m 5s
# 120000
# 120000
# EE 0.15893963768416572
# E_input_E 2.0878758191647364
# IE 3.395193419852676
# global excitatory rate: <neurons_E_rate.G: array([58.6687802])>
# run  30  of  60  completed
# Starting simulation at t=0.36 ks for a duration of 12. s
# 1.0005 s (8%) simulated in 1m 0s, estimated 11m 0s remaining.
# 1.9787 s (16%) simulated in 2m 0s, estimated 10m 8s remaining.
# 2.9636 s (24%) simulated in 3m 0s, estimated 9m 9s remaining.
# 3.966 s (33%) simulated in 4m 0s, estimated 8m 6s remaining.
# 4.9436 s (41%) simulated in 5m 0s, estimated 7m 8s remaining.
# 5.9285 s (49%) simulated in 6m 0s, estimated 6m 9s remaining.
# 6.9269 s (57%) simulated in 7m 0s, estimated 5m 8s remaining.
# 7.8974 s (65%) simulated in 8m 0s, estimated 4m 9s remaining.
# 8.8915 s (74%) simulated in 9m 0s, estimated 3m 9s remaining.
# 9.9868 s (83%) simulated in 10m 0s, estimated 2m 1s remaining.
# 11.0264 s (91%) simulated in 11m 0s, estimated 58s remaining.
# 12. s (100%) simulated in 11m 55s
# 120000
# 120000
# EE 0.15926307899628592
# E_input_E 2.0869866166101723
# IE 3.401742588177316
# global excitatory rate: <neurons_E_rate.G: array([58.54223924])>
# run  31  of  60  completed
# Starting simulation at t=0.372 ks for a duration of 12. s
# 1.0381 s (8%) simulated in 1m 0s, estimated 10m 34s remaining.
# 2.05 s (17%) simulated in 2m 0s, estimated 9m 43s remaining.
# 3.1097 s (25%) simulated in 3m 0s, estimated 8m 35s remaining.
# 4.1641 s (34%) simulated in 4m 0s, estimated 7m 32s remaining.
# 5.1775 s (43%) simulated in 5m 0s, estimated 6m 35s remaining.
# 6.294 s (52%) simulated in 6m 0s, estimated 5m 26s remaining.
# 7.3643 s (61%) simulated in 7m 0s, estimated 4m 24s remaining.
# 8.4101 s (70%) simulated in 8m 0s, estimated 3m 25s remaining.
# 9.5143 s (79%) simulated in 9m 0s, estimated 2m 21s remaining.
# 10.5403 s (87%) simulated in 10m 0s, estimated 1m 23s remaining.
# 11.5578 s (96%) simulated in 11m 0s, estimated 25s remaining.
# 12. s (100%) simulated in 11m 25s
# 120000
# 120000
# EE 0.1604561577158891
# E_input_E 2.0862801583464727
# IE 3.408447268271408
# global excitatory rate: <neurons_E_rate.G: array([58.01474422])>
# run  32  of  60  completed
# Starting simulation at t=0.384 ks for a duration of 12. s
# 1.0585 s (8%) simulated in 1m 0s, estimated 10m 20s remaining.
# 2.0636 s (17%) simulated in 2m 0s, estimated 9m 38s remaining.
# 3.1312 s (26%) simulated in 3m 0s, estimated 8m 30s remaining.
# 4.1802 s (34%) simulated in 4m 0s, estimated 7m 29s remaining.
# 5.1959 s (43%) simulated in 5m 0s, estimated 6m 33s remaining.
# 6.2867 s (52%) simulated in 6m 0s, estimated 5m 27s remaining.
# 7.3793 s (61%) simulated in 7m 0s, estimated 4m 23s remaining.
# 8.4353 s (70%) simulated in 8m 0s, estimated 3m 23s remaining.
# 9.5571 s (79%) simulated in 9m 0s, estimated 2m 18s remaining.
# 10.637 s (88%) simulated in 10m 0s, estimated 1m 17s remaining.
# 11.7201 s (97%) simulated in 11m 0s, estimated 16s remaining.
# 12. s (100%) simulated in 11m 15s
# 120000
# 120000
# EE 0.16030454651685067
# E_input_E 2.0854661008621123
# IE 3.414926643127845
# global excitatory rate: <neurons_E_rate.G: array([58.97807951])>
# run  33  of  60  completed
# Starting simulation at t=0.396 ks for a duration of 12. s
# 1.0907 s (9%) simulated in 1m 0s, estimated 10m 0s remaining.
# 2.1471 s (17%) simulated in 2m 0s, estimated 9m 11s remaining.
# 3.3223 s (27%) simulated in 3m 0s, estimated 7m 50s remaining.
# 4.4936 s (37%) simulated in 4m 0s, estimated 6m 41s remaining.
# 5.655 s (47%) simulated in 5m 0s, estimated 5m 37s remaining.
# 6.8661 s (57%) simulated in 6m 0s, estimated 4m 29s remaining.
# 8.0101 s (66%) simulated in 7m 0s, estimated 3m 29s remaining.
# 9.2357 s (76%) simulated in 8m 0s, estimated 2m 24s remaining.
# 10.4095 s (86%) simulated in 9m 0s, estimated 1m 23s remaining.
# 11.5819 s (96%) simulated in 10m 0s, estimated 22s remaining.
# 12. s (100%) simulated in 10m 20s
# 120000
# 120000
# EE 0.16094027588768417
# E_input_E 2.0846916001519613
# IE 3.4214413539905073
# global excitatory rate: <neurons_E_rate.G: array([58.24323092])>
# run  34  of  60  completed
# Starting simulation at t=0.408 ks for a duration of 12. s
# 1.2184 s (10%) simulated in 1m 0s, estimated 8m 51s remaining.
# 2.4175 s (20%) simulated in 2m 0s, estimated 7m 56s remaining.
# 3.7014 s (30%) simulated in 3m 0s, estimated 6m 44s remaining.
# 4.9076 s (40%) simulated in 4m 0s, estimated 5m 47s remaining.
# 6.1455 s (51%) simulated in 5m 0s, estimated 4m 46s remaining.
# 7.3521 s (61%) simulated in 6m 0s, estimated 3m 48s remaining.
# 8.5495 s (71%) simulated in 7m 0s, estimated 2m 50s remaining.
# 9.8061 s (81%) simulated in 8m 0s, estimated 1m 47s remaining.
# 11.0084 s (91%) simulated in 9m 0s, estimated 49s remaining.
# 12. s (100%) simulated in 9m 49s
# 120000
# 120000
# EE 0.16131722733354661
# E_input_E 2.0839178445910926
# IE 3.4278853631620296
# global excitatory rate: <neurons_E_rate.G: array([58.70767513])>
# run  35  of  60  completed
# Starting simulation at t=0.42 ks for a duration of 12. s
# 1.2385 s (10%) simulated in 1m 0s, estimated 8m 41s remaining.
# 2.4326 s (20%) simulated in 2m 0s, estimated 7m 52s remaining.
# 3.7202 s (31%) simulated in 3m 0s, estimated 6m 41s remaining.
# 4.9218 s (41%) simulated in 4m 0s, estimated 5m 45s remaining.
# 6.1715 s (51%) simulated in 5m 0s, estimated 4m 43s remaining.
# 7.4113 s (61%) simulated in 6m 0s, estimated 3m 43s remaining.
# 8.6447 s (72%) simulated in 7m 0s, estimated 2m 43s remaining.
# 9.9177 s (82%) simulated in 8m 0s, estimated 1m 41s remaining.
# 11.1056 s (92%) simulated in 9m 0s, estimated 43s remaining.
# 12. s (100%) simulated in 9m 43s
# 120000
# 120000
# EE 0.16203883596895902
# E_input_E 2.083215635420356
# IE 3.43418511309956
# global excitatory rate: <neurons_E_rate.G: array([58.62651041])>
# run  36  of  60  completed
# Starting simulation at t=0.432 ks for a duration of 12. s
# 1.2287 s (10%) simulated in 1m 0s, estimated 8m 46s remaining.
# 2.438 s (20%) simulated in 2m 0s, estimated 7m 51s remaining.
# 3.7183 s (30%) simulated in 3m 0s, estimated 6m 41s remaining.
# 4.927 s (41%) simulated in 4m 0s, estimated 5m 45s remaining.
# 6.1723 s (51%) simulated in 5m 0s, estimated 4m 43s remaining.
# 7.3821 s (61%) simulated in 6m 0s, estimated 3m 45s remaining.
# 8.5976 s (71%) simulated in 7m 0s, estimated 2m 46s remaining.
# 9.8418 s (82%) simulated in 8m 0s, estimated 1m 45s remaining.
# 11.0179 s (91%) simulated in 9m 0s, estimated 48s remaining.
# 12. s (100%) simulated in 9m 48s
# 120000
# 120000
# EE 0.16273827247907352
# E_input_E 2.0824986911425922
# IE 3.4404083156307443
# global excitatory rate: <neurons_E_rate.G: array([58.51642251])>
# run  37  of  60  completed
# Starting simulation at t=0.444 ks for a duration of 12. s
# 1.2337 s (10%) simulated in 1m 0s, estimated 8m 44s remaining.
# 2.4123 s (20%) simulated in 2m 0s, estimated 7m 57s remaining.
# 3.6769 s (30%) simulated in 3m 0s, estimated 6m 48s remaining.
# 4.8864 s (40%) simulated in 4m 0s, estimated 5m 49s remaining.
# 6.1102 s (50%) simulated in 5m 0s, estimated 4m 49s remaining.
# 7.3265 s (61%) simulated in 6m 0s, estimated 3m 50s remaining.
# 8.5191 s (70%) simulated in 7m 0s, estimated 2m 52s remaining.
# 9.7716 s (81%) simulated in 8m 0s, estimated 1m 49s remaining.
# 10.9674 s (91%) simulated in 9m 0s, estimated 51s remaining.
# 12. s (100%) simulated in 9m 50s
# 120000
# 120000
# EE 0.1632554607570775
# E_input_E 2.0817992108167584
# IE 3.4467125420605753
# global excitatory rate: <neurons_E_rate.G: array([58.22026602])>
# run  38  of  60  completed
# Starting simulation at t=0.456 ks for a duration of 12. s
# 1.2567 s (10%) simulated in 1m 0s, estimated 8m 33s remaining.
# 2.4689 s (20%) simulated in 2m 0s, estimated 7m 43s remaining.
# 3.7677 s (31%) simulated in 3m 0s, estimated 6m 33s remaining.
# 4.9797 s (41%) simulated in 4m 0s, estimated 5m 38s remaining.
# 6.2496 s (52%) simulated in 5m 0s, estimated 4m 36s remaining.
# 7.467 s (62%) simulated in 6m 0s, estimated 3m 39s remaining.
# 8.6834 s (72%) simulated in 7m 0s, estimated 2m 40s remaining.
# 9.9487 s (82%) simulated in 8m 0s, estimated 1m 39s remaining.
# 11.1512 s (92%) simulated in 9m 0s, estimated 41s remaining.
# 12. s (100%) simulated in 9m 40s
# 120000
# 120000
# EE 0.163831367273038
# E_input_E 2.0811175796364667
# IE 3.452722025141715
# global excitatory rate: <neurons_E_rate.G: array([58.30721559])>
# run  39  of  60  completed
# Starting simulation at t=0.468 ks for a duration of 12. s
# 1.224 s (10%) simulated in 1m 0s, estimated 8m 48s remaining.
# 2.4461 s (20%) simulated in 2m 0s, estimated 7m 49s remaining.
# 3.7477 s (31%) simulated in 3m 0s, estimated 6m 36s remaining.
# 4.9794 s (41%) simulated in 4m 0s, estimated 5m 38s remaining.
# 6.2157 s (51%) simulated in 5m 0s, estimated 4m 39s remaining.
# 7.4135 s (61%) simulated in 6m 0s, estimated 3m 43s remaining.
# 8.5876 s (71%) simulated in 7m 0s, estimated 2m 47s remaining.
# 9.8523 s (82%) simulated in 8m 0s, estimated 1m 45s remaining.
# 11.0524 s (92%) simulated in 9m 0s, estimated 46s remaining.
# 12. s (100%) simulated in 9m 45s
# 120000
# 120000
# EE 0.16411261450471737
# E_input_E 2.0803988671447975
# IE 3.4589324073779584
# global excitatory rate: <neurons_E_rate.G: array([58.1498379])>
# run  40  of  60  completed
# Starting simulation at t=0.48 ks for a duration of 12. s
# 1.2534 s (10%) simulated in 1m 0s, estimated 8m 35s remaining.
# 2.4754 s (20%) simulated in 2m 0s, estimated 7m 42s remaining.
# 3.7799 s (31%) simulated in 3m 0s, estimated 6m 32s remaining.
# 4.9762 s (41%) simulated in 4m 0s, estimated 5m 39s remaining.
# 6.2178 s (51%) simulated in 5m 0s, estimated 4m 39s remaining.
# 7.4307 s (61%) simulated in 6m 0s, estimated 3m 41s remaining.
# 8.6427 s (72%) simulated in 7m 0s, estimated 2m 43s remaining.
# 9.9152 s (82%) simulated in 8m 0s, estimated 1m 41s remaining.
# 11.1245 s (92%) simulated in 9m 0s, estimated 43s remaining.
# 12. s (100%) simulated in 9m 41s
# 120000
# 120000
# EE 0.16479496746092945
# E_input_E 2.0797732550965438
# IE 3.465014607547382
# global excitatory rate: <neurons_E_rate.G: array([58.51976593])>
# run  41  of  60  completed
# Starting simulation at t=0.492 ks for a duration of 12. s
# 1.2645 s (10%) simulated in 1m 0s, estimated 8m 29s remaining.
# 2.4814 s (20%) simulated in 2m 0s, estimated 7m 40s remaining.
# 3.7623 s (31%) simulated in 3m 0s, estimated 6m 34s remaining.
# 4.9546 s (41%) simulated in 4m 0s, estimated 5m 41s remaining.
# 6.1962 s (51%) simulated in 5m 0s, estimated 4m 41s remaining.
# 7.4216 s (61%) simulated in 6m 0s, estimated 3m 42s remaining.
# 8.6305 s (71%) simulated in 7m 0s, estimated 2m 44s remaining.
# 9.8808 s (82%) simulated in 8m 0s, estimated 1m 43s remaining.
# 11.0686 s (92%) simulated in 9m 0s, estimated 45s remaining.
# 12. s (100%) simulated in 9m 44s
# 120000
# 120000
# EE 0.16566883945009686
# E_input_E 2.079161425859328
# IE 3.4710623331519352
# global excitatory rate: <neurons_E_rate.G: array([57.92747736])>
# run  42  of  60  completed
# Starting simulation at t=0.504 ks for a duration of 12. s
# 1.2409 s (10%) simulated in 1m 0s, estimated 8m 40s remaining.
# 2.4202 s (20%) simulated in 2m 0s, estimated 7m 55s remaining.
# 3.6716 s (30%) simulated in 3m 0s, estimated 6m 48s remaining.
# 4.8643 s (40%) simulated in 4m 0s, estimated 5m 52s remaining.
# 6.078 s (50%) simulated in 5m 0s, estimated 4m 52s remaining.
# 7.3012 s (60%) simulated in 6m 0s, estimated 3m 52s remaining.
# 8.4791 s (70%) simulated in 7m 0s, estimated 2m 54s remaining.
# 9.7291 s (81%) simulated in 8m 0s, estimated 1m 52s remaining.
# 10.8914 s (90%) simulated in 9m 0s, estimated 55s remaining.
# 11.9585 s (99%) simulated in 10m 0s, estimated 2s remaining.
# 12. s (100%) simulated in 10m 2s
# 120000
# 120000
# EE 0.16610543680452003
# E_input_E 2.0785665282550827
# IE 3.477196858743788
# global excitatory rate: <neurons_E_rate.G: array([58.34284753])>
# run  43  of  60  completed
# Starting simulation at t=0.516 ks for a duration of 12. s
# 1.0975 s (9%) simulated in 1m 0s, estimated 9m 56s remaining.
# 2.1356 s (17%) simulated in 2m 0s, estimated 9m 14s remaining.
# 3.2409 s (27%) simulated in 3m 0s, estimated 8m 7s remaining.
# 4.3132 s (35%) simulated in 4m 0s, estimated 7m 8s remaining.
# 5.3568 s (44%) simulated in 5m 0s, estimated 6m 12s remaining.
# 6.5265 s (54%) simulated in 6m 0s, estimated 5m 2s remaining.
# 7.6707 s (63%) simulated in 7m 0s, estimated 3m 57s remaining.
# 8.8007 s (73%) simulated in 8m 0s, estimated 2m 55s remaining.
# 9.9264 s (82%) simulated in 9m 0s, estimated 1m 53s remaining.
# 10.9718 s (91%) simulated in 10m 0s, estimated 56s remaining.
# 12. s (100%) simulated in 10m 51s
# 120000
# 120000
# EE 0.1665330849530767
# E_input_E 2.077932896155336
# IE 3.48330244842432
# global excitatory rate: <neurons_E_rate.G: array([58.30306718])>
# run  44  of  60  completed
# Starting simulation at t=0.528 ks for a duration of 12. s
# 1.1023 s (9%) simulated in 1m 0s, estimated 9m 53s remaining.
# 2.1343 s (17%) simulated in 2m 0s, estimated 9m 15s remaining.
# 3.2999 s (27%) simulated in 3m 0s, estimated 7m 55s remaining.
# 4.4178 s (36%) simulated in 4m 0s, estimated 6m 52s remaining.
# 5.4679 s (45%) simulated in 5m 0s, estimated 5m 58s remaining.
# 6.5829 s (54%) simulated in 6m 0s, estimated 4m 56s remaining.
# 7.6482 s (63%) simulated in 7m 0s, estimated 3m 59s remaining.
# 8.7086 s (72%) simulated in 8m 0s, estimated 3m 1s remaining.
# 9.8215 s (81%) simulated in 9m 0s, estimated 2m 0s remaining.
# 10.8997 s (90%) simulated in 10m 0s, estimated 1m 1s remaining.
# 11.9886 s (99%) simulated in 11m 0s, estimated 1s remaining.
# 12. s (100%) simulated in 11m 0s
# 120000
# 120000
# EE 0.16744185177993842
# E_input_E 2.0773818755518714
# IE 3.489264227330122
# global excitatory rate: <neurons_E_rate.G: array([58.71998908])>
# run  45  of  60  completed
# Starting simulation at t=0.54 ks for a duration of 12. s
# 1.1873 s (9%) simulated in 1m 0s, estimated 9m 6s remaining.
# 2.3024 s (19%) simulated in 2m 0s, estimated 8m 25s remaining.
# 3.4462 s (28%) simulated in 3m 0s, estimated 7m 27s remaining.
# 4.5812 s (38%) simulated in 4m 0s, estimated 6m 29s remaining.
# 5.852 s (48%) simulated in 5m 0s, estimated 5m 15s remaining.
# 7.1632 s (59%) simulated in 6m 0s, estimated 4m 3s remaining.
# 8.3787 s (69%) simulated in 7m 0s, estimated 3m 2s remaining.
# 9.5868 s (79%) simulated in 8m 0s, estimated 2m 1s remaining.
# 10.7591 s (89%) simulated in 9m 0s, estimated 1m 2s remaining.
# 11.9752 s (99%) simulated in 10m 0s, estimated 1s remaining.
# 12. s (100%) simulated in 10m 1s
# 120000
# 120000
# EE 0.1678867936014586
# E_input_E 2.076784604492838
# IE 3.4949781070504193
# global excitatory rate: <neurons_E_rate.G: array([58.06646046])>
# run  46  of  60  completed
# Starting simulation at t=0.552 ks for a duration of 12. s
# 1.1427 s (9%) simulated in 1m 0s, estimated 9m 30s remaining.
# 2.261 s (18%) simulated in 2m 0s, estimated 8m 37s remaining.
# 3.465 s (28%) simulated in 3m 0s, estimated 7m 23s remaining.
# 4.5431 s (37%) simulated in 4m 0s, estimated 6m 34s remaining.
# 5.6371 s (46%) simulated in 5m 0s, estimated 5m 39s remaining.
# 6.773 s (56%) simulated in 6m 0s, estimated 4m 38s remaining.
# 7.8475 s (65%) simulated in 7m 0s, estimated 3m 42s remaining.
# 8.9966 s (74%) simulated in 8m 0s, estimated 2m 40s remaining.
# 10.1207 s (84%) simulated in 9m 0s, estimated 1m 40s remaining.
# 11.1783 s (93%) simulated in 10m 0s, estimated 44s remaining.
# 12. s (100%) simulated in 10m 43s
# 120000
# 120000
# EE 0.16838341642902624
# E_input_E 2.07631766959395
# IE 3.5009617964056754
# global excitatory rate: <neurons_E_rate.G: array([57.7862246])>
# run  47  of  60  completed
# Starting simulation at t=0.564 ks for a duration of 12. s
# 1.102 s (9%) simulated in 1m 0s, estimated 9m 53s remaining.
# 2.155 s (17%) simulated in 2m 0s, estimated 9m 8s remaining.
# 3.3006 s (27%) simulated in 3m 0s, estimated 7m 54s remaining.
# 4.4263 s (36%) simulated in 4m 0s, estimated 6m 51s remaining.
# 5.5014 s (45%) simulated in 5m 0s, estimated 5m 54s remaining.
# 6.656 s (55%) simulated in 6m 0s, estimated 4m 49s remaining.
# 7.7369 s (64%) simulated in 7m 0s, estimated 3m 51s remaining.
# 8.8108 s (73%) simulated in 8m 0s, estimated 2m 54s remaining.
# 9.917 s (82%) simulated in 9m 0s, estimated 1m 53s remaining.
# 10.9829 s (91%) simulated in 10m 0s, estimated 56s remaining.
# 12. s (100%) simulated in 10m 55s
# 120000
# 120000
# EE 0.16895042523811532
# E_input_E 2.0757570643866767
# IE 3.50690532964251
# global excitatory rate: <neurons_E_rate.G: array([58.17823572])>
# run  48  of  60  completed
# Starting simulation at t=0.576 ks for a duration of 12. s
# 1.2074 s (10%) simulated in 1m 0s, estimated 8m 56s remaining.
# 2.2643 s (18%) simulated in 2m 0s, estimated 8m 36s remaining.
# 3.4589 s (28%) simulated in 3m 0s, estimated 7m 25s remaining.
# 4.6308 s (38%) simulated in 4m 0s, estimated 6m 22s remaining.
# 5.8089 s (48%) simulated in 5m 0s, estimated 5m 20s remaining.
# 7.0617 s (58%) simulated in 6m 0s, estimated 4m 12s remaining.
# 8.264 s (68%) simulated in 7m 0s, estimated 3m 10s remaining.
# 9.4274 s (78%) simulated in 8m 0s, estimated 2m 11s remaining.
# 10.6486 s (88%) simulated in 9m 0s, estimated 1m 9s remaining.
# 11.7825 s (98%) simulated in 10m 0s, estimated 11s remaining.
# 12. s (100%) simulated in 10m 11s
# 120000
# 120000
# EE 0.16966841593212179
# E_input_E 2.075253600842722
# IE 3.5129215616741774
# global excitatory rate: <neurons_E_rate.G: array([58.32709675])>
# run  49  of  60  completed
# Starting simulation at t=0.588 ks for a duration of 12. s
# 1.1555 s (9%) simulated in 1m 0s, estimated 9m 23s remaining.
# 2.2422 s (18%) simulated in 2m 0s, estimated 8m 42s remaining.
# 3.4053 s (28%) simulated in 3m 0s, estimated 7m 34s remaining.
# 4.5238 s (37%) simulated in 4m 0s, estimated 6m 37s remaining.
# 5.6529 s (47%) simulated in 5m 0s, estimated 5m 37s remaining.
# 6.8331 s (56%) simulated in 6m 0s, estimated 4m 32s remaining.
# 7.9743 s (66%) simulated in 7m 0s, estimated 3m 32s remaining.
# 9.1812 s (76%) simulated in 8m 0s, estimated 2m 27s remaining.
# 10.3957 s (86%) simulated in 9m 0s, estimated 1m 23s remaining.
# 11.6037 s (96%) simulated in 10m 0s, estimated 20s remaining.
# 12. s (100%) simulated in 10m 20s
# 120000
# 120000
# EE 0.1701813531498516
# E_input_E 2.0747516818997003
# IE 3.5185558281600384
# global excitatory rate: <neurons_E_rate.G: array([58.52655756])>
# run  50  of  60  completed
# Starting simulation at t=0.6 ks for a duration of 12. s
# 1.2177 s (10%) simulated in 1m 0s, estimated 8m 51s remaining.
# 2.4239 s (20%) simulated in 2m 0s, estimated 7m 54s remaining.
# 3.5613 s (29%) simulated in 3m 0s, estimated 7m 7s remaining.
# 4.7586 s (39%) simulated in 4m 0s, estimated 6m 5s remaining.
# 5.9143 s (49%) simulated in 5m 0s, estimated 5m 9s remaining.
# 7.1029 s (59%) simulated in 6m 0s, estimated 4m 8s remaining.
# 8.1991 s (68%) simulated in 7m 0s, estimated 3m 15s remaining.
# 9.3992 s (78%) simulated in 8m 0s, estimated 2m 13s remaining.
# 10.4915 s (87%) simulated in 9m 0s, estimated 1m 18s remaining.
# 11.588 s (96%) simulated in 10m 0s, estimated 21s remaining.
# 12. s (100%) simulated in 10m 21s
# 120000
# 120000
# EE 0.17127432098893186
# E_input_E 2.07430304625495
# IE 3.524360938776903
# global excitatory rate: <neurons_E_rate.G: array([57.77995108])>
# run  51  of  60  completed
# Starting simulation at t=0.612 ks for a duration of 12. s
# 1.211 s (10%) simulated in 1m 0s, estimated 8m 55s remaining.
# 2.3399 s (19%) simulated in 2m 0s, estimated 8m 15s remaining.
# 3.5061 s (29%) simulated in 3m 0s, estimated 7m 16s remaining.
# 4.6243 s (38%) simulated in 4m 0s, estimated 6m 23s remaining.
# 5.8092 s (48%) simulated in 5m 0s, estimated 5m 20s remaining.
# 7.0644 s (58%) simulated in 6m 0s, estimated 4m 12s remaining.
# 8.231 s (68%) simulated in 7m 0s, estimated 3m 12s remaining.
# 9.3594 s (77%) simulated in 8m 0s, estimated 2m 15s remaining.
# 10.4675 s (87%) simulated in 9m 0s, estimated 1m 19s remaining.
# 11.5271 s (96%) simulated in 10m 0s, estimated 25s remaining.
# 12. s (100%) simulated in 10m 25s
# 120000
# 120000
# EE 0.17161813025876518
# E_input_E 2.073799075685063
# IE 3.530152803724808
# global excitatory rate: <neurons_E_rate.G: array([58.07303953])>
# run  52  of  60  completed
# Starting simulation at t=0.624 ks for a duration of 12. s
# 1.1609 s (9%) simulated in 1m 0s, estimated 9m 20s remaining.
# 2.2012 s (18%) simulated in 2m 0s, estimated 8m 54s remaining.
# 3.337 s (27%) simulated in 3m 0s, estimated 7m 47s remaining.
# 4.4378 s (36%) simulated in 4m 0s, estimated 6m 49s remaining.
# 5.479 s (45%) simulated in 5m 0s, estimated 5m 57s remaining.
# 6.6052 s (55%) simulated in 6m 0s, estimated 4m 54s remaining.
# 7.6727 s (63%) simulated in 7m 0s, estimated 3m 57s remaining.
# 8.7484 s (72%) simulated in 8m 0s, estimated 2m 58s remaining.
# 9.8724 s (82%) simulated in 9m 0s, estimated 1m 56s remaining.
# 10.9344 s (91%) simulated in 10m 0s, estimated 58s remaining.
# 12. s (100%) simulated in 10m 58s
# 120000
# 120000
# EE 0.17199327643422224
# E_input_E 2.073367118352443
# IE 3.5357388998761077
# global excitatory rate: <neurons_E_rate.G: array([57.90833017])>
# run  53  of  60  completed
# Starting simulation at t=0.636 ks for a duration of 12. s
# 1.087 s (9%) simulated in 1m 0s, estimated 10m 2s remaining.
# 2.1863 s (18%) simulated in 2m 0s, estimated 8m 59s remaining.
# 3.3319 s (27%) simulated in 3m 0s, estimated 7m 48s remaining.
# 4.4117 s (36%) simulated in 4m 0s, estimated 6m 53s remaining.
# 5.4725 s (45%) simulated in 5m 0s, estimated 5m 58s remaining.
# 6.6325 s (55%) simulated in 6m 0s, estimated 4m 51s remaining.
# 7.7382 s (64%) simulated in 7m 0s, estimated 3m 51s remaining.
# 8.8561 s (73%) simulated in 8m 0s, estimated 2m 50s remaining.
# 10.0122 s (83%) simulated in 9m 0s, estimated 1m 47s remaining.
# 11.1201 s (92%) simulated in 10m 0s, estimated 47s remaining.
# 12. s (100%) simulated in 10m 46s
# 120000
# 120000
# EE 0.17316051921758346
# E_input_E 2.072974438802527
# IE 3.5411377797062507
# global excitatory rate: <neurons_E_rate.G: array([58.50055339])>
# run  54  of  60  completed
# Starting simulation at t=0.648 ks for a duration of 12. s
# 1.2084 s (10%) simulated in 1m 0s, estimated 8m 56s remaining.
# 2.3287 s (19%) simulated in 2m 0s, estimated 8m 18s remaining.
# 3.5473 s (29%) simulated in 3m 0s, estimated 7m 9s remaining.
# 4.755 s (39%) simulated in 4m 0s, estimated 6m 6s remaining.
# 5.9595 s (49%) simulated in 5m 0s, estimated 5m 4s remaining.
# 7.2274 s (60%) simulated in 6m 0s, estimated 3m 58s remaining.
# 8.3331 s (69%) simulated in 7m 0s, estimated 3m 5s remaining.
# 9.4652 s (78%) simulated in 8m 0s, estimated 2m 9s remaining.
# 10.6235 s (88%) simulated in 9m 0s, estimated 1m 10s remaining.
# 11.8146 s (98%) simulated in 10m 0s, estimated 9s remaining.
# 12. s (100%) simulated in 10m 9s
# 120000
# 120000
# EE 0.173855709888917
# E_input_E 2.0725391740247545
# IE 3.5467749651356675
# global excitatory rate: <neurons_E_rate.G: array([58.325018])>
# run  55  of  60  completed
# Starting simulation at t=0.66 ks for a duration of 12. s
# 1.2343 s (10%) simulated in 1m 0s, estimated 8m 43s remaining.
# 2.4328 s (20%) simulated in 2m 0s, estimated 7m 52s remaining.
# 3.6129 s (30%) simulated in 3m 0s, estimated 6m 58s remaining.
# 4.6966 s (39%) simulated in 4m 0s, estimated 6m 13s remaining.
# 5.8486 s (48%) simulated in 5m 0s, estimated 5m 16s remaining.
# 7.0098 s (58%) simulated in 6m 0s, estimated 4m 16s remaining.
# 8.1052 s (67%) simulated in 7m 0s, estimated 3m 22s remaining.
# 9.3194 s (77%) simulated in 8m 0s, estimated 2m 18s remaining.
# 10.4248 s (86%) simulated in 9m 0s, estimated 1m 22s remaining.
# 11.558 s (96%) simulated in 10m 0s, estimated 23s remaining.
# 12. s (100%) simulated in 10m 22s
# 120000
# 120000
# EE 0.1740914784567188
# E_input_E 2.0721189355294993
# IE 3.5522719511355954
# global excitatory rate: <neurons_E_rate.G: array([57.67795656])>
# run  56  of  60  completed
# Starting simulation at t=0.672 ks for a duration of 12. s
# 1.1463 s (9%) simulated in 1m 0s, estimated 9m 28s remaining.
# 2.32 s (19%) simulated in 2m 0s, estimated 8m 21s remaining.
# 3.6204 s (30%) simulated in 3m 0s, estimated 6m 57s remaining.
# 4.7774 s (39%) simulated in 4m 0s, estimated 6m 3s remaining.
# 5.9643 s (49%) simulated in 5m 0s, estimated 5m 4s remaining.
# 7.1192 s (59%) simulated in 6m 0s, estimated 4m 7s remaining.
# 8.1865 s (68%) simulated in 7m 0s, estimated 3m 16s remaining.
# 9.4457 s (78%) simulated in 8m 0s, estimated 2m 10s remaining.
# 10.6467 s (88%) simulated in 9m 0s, estimated 1m 9s remaining.
# 11.7379 s (97%) simulated in 10m 0s, estimated 13s remaining.
# 12. s (100%) simulated in 10m 13s
# 120000
# 120000
# EE 0.17447750926752473
# E_input_E 2.0717139244624234
# IE 3.5580956427814145
# global excitatory rate: <neurons_E_rate.G: array([57.77601751])>
# run  57  of  60  completed
# Starting simulation at t=0.684 ks for a duration of 12. s
# 1.2188 s (10%) simulated in 1m 0s, estimated 8m 51s remaining.
# 2.3135 s (19%) simulated in 2m 0s, estimated 8m 23s remaining.
# 3.5518 s (29%) simulated in 3m 0s, estimated 7m 8s remaining.
# 4.6476 s (38%) simulated in 4m 0s, estimated 6m 20s remaining.
# 5.8265 s (48%) simulated in 5m 0s, estimated 5m 18s remaining.
# 7.0456 s (58%) simulated in 6m 0s, estimated 4m 13s remaining.
# 8.2139 s (68%) simulated in 7m 0s, estimated 3m 14s remaining.
# 9.3517 s (77%) simulated in 8m 0s, estimated 2m 16s remaining.
# 10.4538 s (87%) simulated in 9m 0s, estimated 1m 20s remaining.
# 11.5964 s (96%) simulated in 10m 0s, estimated 21s remaining.
# 12. s (100%) simulated in 10m 21s
# 120000
# 120000
# EE 0.17542138293938114
# E_input_E 2.0713382372288804
# IE 3.563736969193293
# global excitatory rate: <neurons_E_rate.G: array([57.37896603])>
# run  58  of  60  completed
# Starting simulation at t=0.696 ks for a duration of 12. s
# 1.1558 s (9%) simulated in 1m 0s, estimated 9m 23s remaining.
# 2.2716 s (18%) simulated in 2m 0s, estimated 8m 34s remaining.
# 3.5349 s (29%) simulated in 3m 0s, estimated 7m 11s remaining.
# 4.7183 s (39%) simulated in 4m 0s, estimated 6m 10s remaining.
# 5.8137 s (48%) simulated in 5m 0s, estimated 5m 19s remaining.
# 6.9425 s (57%) simulated in 6m 0s, estimated 4m 22s remaining.
# 8.0374 s (66%) simulated in 7m 0s, estimated 3m 27s remaining.
# 9.153 s (76%) simulated in 8m 0s, estimated 2m 29s remaining.
# 10.2332 s (85%) simulated in 9m 0s, estimated 1m 33s remaining.
# 11.2851 s (94%) simulated in 10m 0s, estimated 38s remaining.
# 12. s (100%) simulated in 10m 38s
# 120000
# 120000
# EE 0.1756394429458151
# E_input_E 2.070957278834026
# IE 3.5692744850424583
# global excitatory rate: <neurons_E_rate.G: array([57.79790727])>
# run  59  of  60  completed
# Starting simulation at t=0.708 ks for a duration of 12. s
# 1.1832 s (9%) simulated in 1m 0s, estimated 9m 9s remaining.
# 2.2331 s (18%) simulated in 2m 0s, estimated 8m 45s remaining.
# 3.3777 s (28%) simulated in 3m 0s, estimated 7m 40s remaining.
# 4.4632 s (37%) simulated in 4m 0s, estimated 6m 45s remaining.
# 5.5221 s (46%) simulated in 5m 0s, estimated 5m 52s remaining.
# 6.6865 s (55%) simulated in 6m 0s, estimated 4m 46s remaining.
# 7.7585 s (64%) simulated in 7m 0s, estimated 3m 50s remaining.
# 8.8404 s (73%) simulated in 8m 0s, estimated 2m 52s remaining.
# 9.9732 s (83%) simulated in 9m 0s, estimated 1m 50s remaining.
# 11.0245 s (91%) simulated in 10m 0s, estimated 53s remaining.
# 12. s (100%) simulated in 10m 51s
# 120000
# 120000
# EE 0.17620018802468615
# E_input_E 2.070635400368009
# IE 3.5748630605399345
# global excitatory rate: <neurons_E_rate.G: array([57.64493967])>
# run  60  of  60  completed
# saving data
# saving data

# %%
test = exp._to_weight_matrix(synapse_group=exp.synapses['E_input_E'], w_key='w_exc_plastic')
test2 = exp._to_weight_matrix(synapse_group=exp.synapses['EE'], w_key='w_exc_plastic')
test3 = exp._to_weight_matrix(synapse_group=exp.synapses['IE'], w_key='w_inh_plastic')
test4 = exp._to_weight_matrix(synapse_group=exp.synapses['II'], w_key='w_inh_plastic')
test5 = exp._to_weight_matrix(synapse_group=exp.synapses['EI'], w_key='w_exc_plastic_init')

# %%
plt.imshow(test2)
plt.colorbar()
plt.figure()
plt.imshow(test[:,exp.sort_by_receptive_field_loc], aspect='auto')
plt.colorbar()
plt.figure()
# plt.imshow(test[:1000,40:500], aspect='auto')
# plt.colorbar()

plt.imshow(test4, aspect='auto')
plt.colorbar()
plt.figure()
plt.imshow(test5, aspect='auto')
plt.colorbar()

# %%
for i in range(10):
    plt.figure()
    plt.imshow(test[:,i].reshape((64,64),order='F'))
    plt.colorbar()
