# %%
import networks
import equations
from brian2 import *
reload(equations)
reload(networks)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-9a9cada2ce7c> in <module>()
# ----> 1 import networks
#       2 import equations
#       3 from brian2 import *
#       4 reload(equations)
#       5 reload(networks)
#
# C:\Users\Greg Kronberg\Google Drive\Work\GitHub\DCS-LTP-IntegrateAndFire-Clopath-Network\networks.py in <module>()
# ----> 1 from brian2 import *
#       2 import equations
#       3 import copy
#       4
#       5 # parameters
#
# ImportError: No module named brian2

# %%
exp = networks.exp_litwinkumar_test_2()

# %%
exp.run()

# %%
exp.net.run(10*ms)
# Out:
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     _lio_2 = 1.0 / mV
#     _lio_3 = 0.0 - (theta_high / mV)
#     _lio_4 = A_LTP * _saturated_synapses_EE_dt
#     _lio_5 = (-1.0) * (A_LTP * tau_x)
#     _lio_6 = 1.0 / tau_x
#     _lio_7 = int_(update_ampa_online) * g_max_ampa
#                 ^
# ------------------------------------------------------------
#
# C:\Users\Greg Kronberg\.cython\brian_extensions\_cython_magic_d60df84fa828163bec34ca54273bdb9b.pyx:200:17: ambiguous overloaded method
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     _lio_5 = (-1.0) * (A_LTP * tau_x)
#     _lio_6 = 1.0 / tau_x
#     _lio_7 = int_(update_ampa_online) * g_max_ampa
#     _lio_8 = int_(1 - update_ampa_online) * g_max_ampa
#     _lio_9 = int_(1 - include_homeostatic)
#     _lio_10 = (int_(include_homeostatic) * A_LTD) / v_target
#                   ^
# ...
